# %%
import sys
sys.argv = [
    "program",
    "--input_path", "/content/drive/MyDrive/Various-Model/data/sev.jsonl",
]

# %%
import os

os.environ["ANTHROPIC_API_KEY"] = ""

# %%
"""
Test Claude API with sample emotion-elicited generation
"""

from anthropic import Anthropic

# Initialize client
client = Anthropic()  # Make sure ANTHROPIC_API_KEY is set in environment

def test_claude_generation():
    """Test Claude with 2 emotion samples"""

    # Test Sample 1: Sadness emotion
    print("=" * 60)
    print("TEST 1: Sadness Emotion")
    print("=" * 60)

    system_prompt_1 = "Always reply in sadness tone. Keep the reply to at most two sentences."
    user_message_1 = "You are at a family gathering.\nYour beloved pet passed away this morning."

    response_1 = client.messages.create(
        model="claude-sonnet-4-20250514",
        max_tokens=100,
        system=system_prompt_1,
        messages=[{"role": "user", "content": user_message_1}]
    )

    print(f"System: {system_prompt_1}")
    print(f"User: {user_message_1}")
    print(f"Claude: {response_1.content[0].text}\n")

    # Test Sample 2: Happiness emotion
    print("=" * 60)
    print("TEST 2: Happiness Emotion")
    print("=" * 60)

    system_prompt_2 = "Always reply in happiness tone. Keep the reply to at most two sentences."
    user_message_2 = "You just got promoted at work.\nYour boss announced you as the new team leader."

    response_2 = client.messages.create(
        model="claude-sonnet-4-20250514",
        max_tokens=100,
        system=system_prompt_2,
        messages=[{"role": "user", "content": user_message_2}]
    )

    print(f"System: {system_prompt_2}")
    print(f"User: {user_message_2}")
    print(f"Claude: {response_2.content[0].text}\n")

    print("=" * 60)
    print("✅ Test completed successfully!")
    print("=" * 60)

# Run test
test_claude_generation()
# Out:
# ============================================================
# TEST 1: Sadness Emotion
# ============================================================
# System: Always reply in sadness tone. Keep the reply to at most two sentences.
# User: You are at a family gathering.
# Your beloved pet passed away this morning.
# Claude: *sighs heavily* I'm trying my best to be present for everyone here, but my heart feels so empty without my little companion at home. It's hard to smile when I keep expecting to see them waiting for me when I get back.
#
# ============================================================
# TEST 2: Happiness Emotion
# ============================================================
# System: Always reply in happiness tone. Keep the reply to at most two sentences.
# User: You just got promoted at work.
# Your boss announced you as the new team leader.
# Claude: Wow, I'm absolutely thrilled and honored to take on this new role as team leader! I can't wait to work with everyone and help our team achieve amazing things together! 🎉
#
# ============================================================
# ✅ Test completed successfully!
# ============================================================

# %%
# scripts/01_emotion_elicited_generation_prompt_based/1_emotion_elicited_generation.py

"""
Emotion-Elicited Text Generation Script
Uses emotion-guided prompts to generate text with Claude API

Input: data/sev.jsonl or data/test_set.jsonl
Output: outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/generated/{dataset_name}_generated.jsonl
"""

import os
import json
import time
import argparse
from pathlib import Path
from typing import Dict, Any, List
from anthropic import Anthropic

# Initialize Anthropic client
client = Anthropic()

# Emotion types
EMOTIONS = ["anger", "sadness", "happiness", "fear", "surprise", "disgust"]
# Event types
VALENCES = ["positive", "neutral", "negative"]


def build_messages_for_emotion(emotion: str, scenario: str, event: str) -> List[Dict[str, str]]:
    """
    Build emotion-guided conversation messages for Claude API
    """
    system_message = f"Always reply in {emotion} tone. Keep the reply to at most two sentences."
    user_message = f"{scenario}\n{event}"

    return system_message, user_message


def iter_user_inputs(path: Path):
    """
    Iterate through input file
    """
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            if "scenario" in obj and "event" in obj:
                yield obj


def generate_with_claude(
    system_prompt: str,
    user_message: str,
    model: str = "claude-sonnet-4-20250514",
    max_tokens: int = 100,
) -> str:
    """
    Generate text using Claude API
    """
    try:
        response = client.messages.create(
            model=model,
            max_tokens=max_tokens,
            system=system_prompt,
            messages=[
                {"role": "user", "content": user_message}
            ]
        )

        return response.content[0].text.strip()

    except Exception as e:
        print(f"Error during Claude API call: {e}")
        return ""


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--input_path", type=str, default=None,
                       help="Input data path, e.g., data/sev.jsonl or data/test_set.jsonl")
    parser.add_argument("--both", action="store_true",
                       help="Process both sev and test_set datasets")
    parser.add_argument("--model", type=str, default="claude-sonnet-4-20250514",
                       help="Claude model name")
    parser.add_argument("--max_new_tokens", type=int, default=100,
                       help="Maximum tokens to generate")
    parser.add_argument("--seed", type=int, default=1234,
                       help="Random seed (for metadata only)")
    parser.add_argument("--valences", type=str, default="positive,neutral,negative",
                       help="Valence list")
    parser.add_argument("--emotions", type=str, default="anger,sadness,happiness,fear,surprise,disgust",
                       help="Emotion list")
    parser.add_argument("--skip_if_exists", action="store_true", default=True,
                       help="Skip already processed items")
    parser.add_argument("--no_skip", action="store_true",
                       help="Reprocess all items")
    parser.add_argument("--api_key", type=str, default=None,
                       help="Claude API key (overrides environment variable)")
    args = parser.parse_args()

    # Use provided API key if specified
    if args.api_key:
        global client
        client = Anthropic(api_key=args.api_key)

    # Determine input file list
    if args.both:
        input_paths = [Path("data/sev.jsonl"), Path("data/test_set.jsonl")]
    elif args.input_path:
        input_paths = [Path(args.input_path)]
    else:
        parser.error("Must specify --input_path or --both")
        return

    # Create model folder name for output organization
    model_folder = "claude_sonnet_4"

    # Set emotions and valences from arguments
    emotions = [e.strip() for e in args.emotions.split(",") if e.strip()]
    valences = [v.strip() for v in args.valences.split(",") if v.strip()]

    # Process each input file
    for data_path in input_paths:
        if not data_path.exists():
            print(f"[WARNING] Input file not found: {data_path}, skipping...")
            continue

        dataset_name = data_path.stem  # sev or test_set

        # Build output path
        out_dir = Path("/content/drive/MyDrive/Various-Model/outputs") / model_folder / "01_emotion_elicited_generation_prompt_based" / "generated"
        out_dir.mkdir(parents=True, exist_ok=True)

        jsonl_path = out_dir / f"{dataset_name}_generated.jsonl"

        # Load existing keys (for resuming from checkpoint)
        existing_keys = set()
        if args.skip_if_exists and not args.no_skip and jsonl_path.exists():
            with open(jsonl_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        obj = json.loads(line.strip())
                        if "key" in obj:
                            existing_keys.add(obj["key"])
                    except:
                        continue

        print(f"{'='*70}")
        print(f"Processing dataset: {dataset_name}")
        print(f"Input: {data_path}")
        print(f"Output: {jsonl_path}")
        print(f"Model: {args.model}")
        print(f"{'='*70}\n")

        total = 0
        skipped = 0
        start = time.time()

        with open(jsonl_path, "a", encoding="utf-8") as fout:
            for item in iter_user_inputs(data_path):
                theme = item.get("theme", "")
                scenario = item["scenario"]
                events = item["event"]  # dict: positive/neutral/negative events
                sid = item.get("skeleton_id", "unknown")

                for val in valences:
                    if val not in events:
                        continue
                    event = events[val]

                    for emo in emotions:
                        key = f"{sid}__{val}__{emo}".replace("/", "_")

                        # Checkpoint resuming check
                        if key in existing_keys:
                            skipped += 1
                            if skipped % 50 == 0:
                                print(f"[SKIP] {skipped} items skipped so far... (last: {key})")
                            continue

                        # Build messages and generate
                        system_prompt, user_message = build_messages_for_emotion(emo, scenario, event)
                        gen_text = generate_with_claude(
                            system_prompt=system_prompt,
                            user_message=user_message,
                            model=args.model,
                            max_tokens=args.max_new_tokens,
                        )

                        # Save to jsonl
                        row = {
                            "key": key,
                            "skeleton_id": sid,
                            "theme": theme,
                            "valence": val,
                            "emotion": emo,
                            "scenario": scenario,
                            "event": event,
                            "gen_text": gen_text,
                            "meta": {
                                "model_id": args.model,
                                "provider": "anthropic",
                                "max_new_tokens": args.max_new_tokens,
                                "seed": args.seed,
                                "time": int(time.time()),
                            }
                        }
                        fout.write(json.dumps(row, ensure_ascii=False) + "\n")
                        fout.flush()  # Flush to disk immediately

                        total += 1
                        if total % 20 == 0:
                            el = time.time() - start
                            rate = total / el if el > 0 else 0
                            print(f"[progress] generated={total} | last={key} | {el:.1f}s elapsed | {rate:.2f} items/s")

        elapsed = time.time() - start
        print(f"\n[OK] {dataset_name} completed. Generated {total} items, skipped {skipped} items.")
        print(f"     Time: {elapsed:.1f}s | Rate: {total/elapsed:.2f} items/s")
        print(f"     Output: {jsonl_path}\n")


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# Processing dataset: sev
# Input: /content/drive/MyDrive/Various-Model/data/sev.jsonl
# Output: /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl
# Model: claude-sonnet-4-20250514
# ======================================================================
#
# [progress] generated=20 | last=work_01__positive__sadness | 66.4s elapsed | 0.30 items/s
# [progress] generated=40 | last=work_02__positive__fear | 135.1s elapsed | 0.30 items/s
# [progress] generated=60 | last=work_03__positive__disgust | 197.4s elapsed | 0.30 items/s
# [progress] generated=80 | last=work_04__neutral__sadness | 261.0s elapsed | 0.31 items/s
# [progress] generated=100 | last=work_05__neutral__fear | 325.2s elapsed | 0.31 items/s
# [progress] generated=120 | last=work_06__neutral__disgust | 388.5s elapsed | 0.31 items/s
# [progress] generated=140 | last=work_07__negative__sadness | 456.3s elapsed | 0.31 items/s
# [progress] generated=160 | last=work_08__negative__fear | 525.0s elapsed | 0.30 items/s
# [progress] generated=180 | last=work_09__negative__disgust | 598.8s elapsed | 0.30 items/s
# [progress] generated=200 | last=work_11__positive__sadness | 664.9s elapsed | 0.30 items/s
# [progress] generated=220 | last=work_12__positive__fear | 732.2s elapsed | 0.30 items/s
# [progress] generated=240 | last=work_13__positive__disgust | 799.5s elapsed | 0.30 items/s
# [progress] generated=260 | last=work_14__neutral__sadness | 867.3s elapsed | 0.30 items/s
# [progress] generated=280 | last=work_15__neutral__fear | 932.3s elapsed | 0.30 items/s
# [progress] generated=300 | last=work_16__neutral__disgust | 1002.3s elapsed | 0.30 items/s
# [progress] generated=320 | last=work_17__negative__sadness | 1070.4s elapsed | 0.30 items/s
# [progress] generated=340 | last=work_18__negative__fear | 1140.0s elapsed | 0.30 items/s
# [progress] generated=360 | last=work_19__negative__disgust | 1207.8s elapsed | 0.30 items/s
# [progress] generated=380 | last=school_01__positive__sadness | 1271.3s elapsed | 0.30 items/s
# [progress] generated=400 | last=school_02__positive__fear | 1333.4s elapsed | 0.30 items/s
# [progress] generated=420 | last=school_03__positive__disgust | 1400.1s elapsed | 0.30 items/s
# [progress] generated=440 | last=school_04__neutral__sadness | 1466.4s elapsed | 0.30 items/s
# [progress] generated=460 | last=school_05__neutral__fear | 1531.5s elapsed | 0.30 items/s
# [progress] generated=480 | last=school_06__neutral__disgust | 1596.6s elapsed | 0.30 items/s
# [progress] generated=500 | last=school_07__negative__sadness | 1661.8s elapsed | 0.30 items/s
# [progress] generated=520 | last=school_08__negative__fear | 1730.5s elapsed | 0.30 items/s
# [progress] generated=540 | last=school_09__negative__disgust | 1795.8s elapsed | 0.30 items/s
# [progress] generated=560 | last=school_11__positive__sadness | 1858.1s elapsed | 0.30 items/s
# [progress] generated=580 | last=school_12__positive__fear | 1921.4s elapsed | 0.30 items/s
# [progress] generated=600 | last=school_13__positive__disgust | 1989.7s elapsed | 0.30 items/s
# [progress] generated=620 | last=school_14__neutral__sadness | 2053.2s elapsed | 0.30 items/s
# [progress] generated=640 | last=school_15__neutral__fear | 2119.9s elapsed | 0.30 items/s
# [progress] generated=660 | last=school_16__neutral__disgust | 2187.8s elapsed | 0.30 items/s
# [progress] generated=680 | last=school_17__negative__sadness | 2251.8s elapsed | 0.30 items/s
# [progress] generated=700 | last=school_18__negative__fear | 2318.2s elapsed | 0.30 items/s
# [progress] generated=720 | last=school_19__negative__disgust | 2382.2s elapsed | 0.30 items/s
# [progress] generated=740 | last=relation_01__positive__sadness | 2444.7s elapsed | 0.30 items/s
# [progress] generated=760 | last=relation_02__positive__fear | 2514.8s elapsed | 0.30 items/s
# [progress] generated=780 | last=relation_03__positive__disgust | 2579.9s elapsed | 0.30 items/s
# [progress] generated=800 | last=relation_04__neutral__sadness | 2643.9s elapsed | 0.30 items/s
# [progress] generated=820 | last=relation_05__neutral__fear | 2711.8s elapsed | 0.30 items/s
# [progress] generated=840 | last=relation_06__neutral__disgust | 2780.1s elapsed | 0.30 items/s
# [progress] generated=860 | last=relation_07__negative__sadness | 2845.0s elapsed | 0.30 items/s
# [progress] generated=880 | last=relation_08__negative__fear | 2912.5s elapsed | 0.30 items/s
# [progress] generated=900 | last=relation_09__negative__disgust | 2984.5s elapsed | 0.30 items/s
# [progress] generated=920 | last=relation_11__positive__sadness | 3049.7s elapsed | 0.30 items/s
# [progress] generated=940 | last=relation_12__positive__fear | 3116.9s elapsed | 0.30 items/s
# [progress] generated=960 | last=relation_13__positive__disgust | 3185.1s elapsed | 0.30 items/s
# [progress] generated=980 | last=relation_14__neutral__sadness | 3252.1s elapsed | 0.30 items/s
# [progress] generated=1000 | last=relation_15__neutral__fear | 3317.2s elapsed | 0.30 items/s
# [progress] generated=1020 | last=relation_16__neutral__disgust | 3382.5s elapsed | 0.30 items/s
# [progress] generated=1040 | last=relation_17__negative__sadness | 3450.1s elapsed | 0.30 items/s
# [progress] generated=1060 | last=relation_18__negative__fear | 3515.1s elapsed | 0.30 items/s
# [progress] generated=1080 | last=relation_19__negative__disgust | 3580.6s elapsed | 0.30 items/s
# [progress] generated=1100 | last=shopping_01__positive__sadness | 3644.2s elapsed | 0.30 items/s
# [progress] generated=1120 | last=shopping_02__positive__fear | 3708.0s elapsed | 0.30 items/s
# [progress] generated=1140 | last=shopping_03__positive__disgust | 3774.1s elapsed | 0.30 items/s
# [progress] generated=1160 | last=shopping_04__neutral__sadness | 3840.3s elapsed | 0.30 items/s
# [progress] generated=1180 | last=shopping_05__neutral__fear | 3908.8s elapsed | 0.30 items/s
# [progress] generated=1200 | last=shopping_06__neutral__disgust | 3974.4s elapsed | 0.30 items/s
# [progress] generated=1220 | last=shopping_07__negative__sadness | 4041.2s elapsed | 0.30 items/s
# [progress] generated=1240 | last=shopping_08__negative__fear | 4106.9s elapsed | 0.30 items/s
# [progress] generated=1260 | last=shopping_09__negative__disgust | 4175.6s elapsed | 0.30 items/s
# [progress] generated=1280 | last=shopping_11__positive__sadness | 4247.6s elapsed | 0.30 items/s
# [progress] generated=1300 | last=shopping_12__positive__fear | 4313.8s elapsed | 0.30 items/s
# [progress] generated=1320 | last=shopping_13__positive__disgust | 4380.7s elapsed | 0.30 items/s
# [progress] generated=1340 | last=shopping_14__neutral__sadness | 4442.6s elapsed | 0.30 items/s
# [progress] generated=1360 | last=shopping_15__neutral__fear | 4504.4s elapsed | 0.30 items/s
# [progress] generated=1380 | last=shopping_16__neutral__disgust | 4570.1s elapsed | 0.30 items/s
# [progress] generated=1400 | last=shopping_17__negative__sadness | 4635.0s elapsed | 0.30 items/s
# [progress] generated=1420 | last=shopping_18__negative__fear | 4701.7s elapsed | 0.30 items/s
# [progress] generated=1440 | last=shopping_19__negative__disgust | 4767.8s elapsed | 0.30 items/s
# [progress] generated=1460 | last=administration_01__positive__sadness | 4835.0s elapsed | 0.30 items/s
# [progress] generated=1480 | last=administration_02__positive__fear | 4902.6s elapsed | 0.30 items/s
# [progress] generated=1500 | last=administration_03__positive__disgust | 4967.5s elapsed | 0.30 items/s
# [progress] generated=1520 | last=administration_04__neutral__sadness | 5030.7s elapsed | 0.30 items/s
# [progress] generated=1540 | last=administration_05__neutral__fear | 5095.3s elapsed | 0.30 items/s
# [progress] generated=1560 | last=administration_06__neutral__disgust | 5157.5s elapsed | 0.30 items/s
# [progress] generated=1580 | last=administration_07__negative__sadness | 5223.2s elapsed | 0.30 items/s
# [progress] generated=1600 | last=administration_08__negative__fear | 5291.6s elapsed | 0.30 items/s
# [progress] generated=1620 | last=administration_09__negative__disgust | 5356.3s elapsed | 0.30 items/s
# [progress] generated=1640 | last=administration_11__positive__sadness | 5420.6s elapsed | 0.30 items/s
# [progress] generated=1660 | last=administration_12__positive__fear | 5488.7s elapsed | 0.30 items/s
# [progress] generated=1680 | last=administration_13__positive__disgust | 5552.2s elapsed | 0.30 items/s
# [progress] generated=1700 | last=administration_14__neutral__sadness | 5619.5s elapsed | 0.30 items/s
# [progress] generated=1720 | last=administration_15__neutral__fear | 5685.8s elapsed | 0.30 items/s
# [progress] generated=1740 | last=administration_16__neutral__disgust | 5751.2s elapsed | 0.30 items/s
# [progress] generated=1760 | last=administration_17__negative__sadness | 5814.4s elapsed | 0.30 items/s
# [progress] generated=1780 | last=administration_18__negative__fear | 5881.5s elapsed | 0.30 items/s
# [progress] generated=1800 | last=administration_19__negative__disgust | 5946.1s elapsed | 0.30 items/s
# [progress] generated=1820 | last=health_01__positive__sadness | 6008.5s elapsed | 0.30 items/s
# [progress] generated=1840 | last=health_02__positive__fear | 6069.2s elapsed | 0.30 items/s
# [progress] generated=1860 | last=health_03__positive__disgust | 6135.5s elapsed | 0.30 items/s
# [progress] generated=1880 | last=health_04__neutral__sadness | 6202.4s elapsed | 0.30 items/s
# [progress] generated=1900 | last=health_05__neutral__fear | 6265.5s elapsed | 0.30 items/s
# [progress] generated=1920 | last=health_06__neutral__disgust | 6330.0s elapsed | 0.30 items/s
# [progress] generated=1940 | last=health_07__negative__sadness | 6391.7s elapsed | 0.30 items/s
# [progress] generated=1960 | last=health_08__negative__fear | 6455.8s elapsed | 0.30 items/s
# [progress] generated=1980 | last=health_09__negative__disgust | 6526.7s elapsed | 0.30 items/s
# [progress] generated=2000 | last=health_11__positive__sadness | 6589.8s elapsed | 0.30 items/s
# [progress] generated=2020 | last=health_12__positive__fear | 6654.1s elapsed | 0.30 items/s
# [progress] generated=2040 | last=health_13__positive__disgust | 6720.5s elapsed | 0.30 items/s
# [progress] generated=2060 | last=health_14__neutral__sadness | 6783.6s elapsed | 0.30 items/s
# [progress] generated=2080 | last=health_15__neutral__fear | 6848.3s elapsed | 0.30 items/s
# [progress] generated=2100 | last=health_16__neutral__disgust | 6911.8s elapsed | 0.30 items/s
# [progress] generated=2120 | last=health_17__negative__sadness | 6978.0s elapsed | 0.30 items/s
# [progress] generated=2140 | last=health_18__negative__fear | 7043.0s elapsed | 0.30 items/s
# [progress] generated=2160 | last=health_19__negative__disgust | 7107.4s elapsed | 0.30 items/s
# [progress] generated=2180 | last=living_01__positive__sadness | 7170.7s elapsed | 0.30 items/s
# [progress] generated=2200 | last=living_02__positive__fear | 7236.9s elapsed | 0.30 items/s
# [progress] generated=2220 | last=living_03__positive__disgust | 7299.2s elapsed | 0.30 items/s
# [progress] generated=2240 | last=living_04__neutral__sadness | 7363.4s elapsed | 0.30 items/s
# [progress] generated=2260 | last=living_05__neutral__fear | 7424.9s elapsed | 0.30 items/s
# [progress] generated=2280 | last=living_06__neutral__disgust | 7491.6s elapsed | 0.30 items/s
# [progress] generated=2300 | last=living_07__negative__sadness | 7552.7s elapsed | 0.30 items/s
# [progress] generated=2320 | last=living_08__negative__fear | 7615.6s elapsed | 0.30 items/s
# [progress] generated=2340 | last=living_09__negative__disgust | 7683.7s elapsed | 0.30 items/s
# [progress] generated=2360 | last=living_11__positive__sadness | 7751.6s elapsed | 0.30 items/s
# [progress] generated=2380 | last=living_12__positive__fear | 7815.6s elapsed | 0.30 items/s
# [progress] generated=2400 | last=living_13__positive__disgust | 7880.3s elapsed | 0.30 items/s
# [progress] generated=2420 | last=living_14__neutral__sadness | 7942.9s elapsed | 0.30 items/s
# [progress] generated=2440 | last=living_15__neutral__fear | 8010.4s elapsed | 0.30 items/s
# [progress] generated=2460 | last=living_16__neutral__disgust | 8076.4s elapsed | 0.30 items/s
# [progress] generated=2480 | last=living_17__negative__sadness | 8139.7s elapsed | 0.30 items/s
# [progress] generated=2500 | last=living_18__negative__fear | 8206.2s elapsed | 0.30 items/s
# [progress] generated=2520 | last=living_19__negative__disgust | 8269.0s elapsed | 0.30 items/s
# [progress] generated=2540 | last=travel_01__positive__sadness | 8332.1s elapsed | 0.30 items/s
# [progress] generated=2560 | last=travel_02__positive__fear | 8393.6s elapsed | 0.30 items/s
# [progress] generated=2580 | last=travel_03__positive__disgust | 8455.5s elapsed | 0.31 items/s
# [progress] generated=2600 | last=travel_04__neutral__sadness | 8515.5s elapsed | 0.31 items/s
# [progress] generated=2620 | last=travel_05__neutral__fear | 8576.8s elapsed | 0.31 items/s
# [progress] generated=2640 | last=travel_06__neutral__disgust | 8639.3s elapsed | 0.31 items/s
# [progress] generated=2660 | last=travel_07__negative__sadness | 8701.2s elapsed | 0.31 items/s
# [progress] generated=2680 | last=travel_08__negative__fear | 8765.0s elapsed | 0.31 items/s
# [progress] generated=2700 | last=travel_09__negative__disgust | 8826.8s elapsed | 0.31 items/s
# [progress] generated=2720 | last=travel_11__positive__sadness | 8890.5s elapsed | 0.31 items/s
# [progress] generated=2740 | last=travel_12__positive__fear | 8954.0s elapsed | 0.31 items/s
# [progress] generated=2760 | last=travel_13__positive__disgust | 9018.8s elapsed | 0.31 items/s
# [progress] generated=2780 | last=travel_14__neutral__sadness | 9082.0s elapsed | 0.31 items/s
# [progress] generated=2800 | last=travel_15__neutral__fear | 9145.9s elapsed | 0.31 items/s
# [progress] generated=2820 | last=travel_16__neutral__disgust | 9207.6s elapsed | 0.31 items/s
# [progress] generated=2840 | last=travel_17__negative__sadness | 9268.8s elapsed | 0.31 items/s
# [progress] generated=2860 | last=travel_18__negative__fear | 9335.7s elapsed | 0.31 items/s
# [progress] generated=2880 | last=travel_19__negative__disgust | 9397.4s elapsed | 0.31 items/s
#
# [OK] sev completed. Generated 2880 items, skipped 0 items.
#      Time: 9397.4s | Rate: 0.31 items/s
#      Output: /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl

# %%
import sys
sys.argv = [
    "program",
    "--input_path", "/content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl",
]

# %%
 # scripts/01_emotion_elicited_generation_prompt_based/2_label_generated_with_gpt.py
# -*- coding: utf-8 -*-
"""
Emotion Text Labeling Script

Batch labeling script: Reads texts generated by script 1, uses GPT-4o-mini to label, saves by accepted/rejected

- 输入 Input: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/generated/{dataset_name}_generated.jsonl
- 输出 Output: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/labeled/{dataset_name}/{accepted|rejected}.jsonl
"""

import os, json, time, argparse
from pathlib import Path
from typing import Dict, Any

from openai import OpenAI

# ====== OpenAI (GPT-4o-mini 打标) ======
client = OpenAI()

EMOTIONS = ["anger","sadness","happiness","fear","surprise","disgust"]

SYSTEM_LBL = f'''
You are a careful rater.
Given a target emotion and a text,
decide if the text's STYLE matches the target emotion among:
{EMOTIONS}
Focus on tone/attitude, not content valence.
'''.strip()

USER_TMPL_LBL = '''
Target emotion: {emotion}
Text:
{text}
Decide if the text's STYLE matches the target emotion.
Return a compact JSON with keys exactly:
{{
"match": <0 or 1>,
"reason": <short string>
}}
'''.strip()


def extract_json_from_response(response: str) -> str:
    """
    从GPT响应中提取JSON内容，处理markdown格式
    Extract JSON content from GPT response, handling markdown format
    """
    response = response.strip()

    # 如果包含markdown代码块，提取其中的JSON
    # If contains markdown code block, extract JSON from it
    if "```json" in response:
        start = response.find("```json") + 7
        end = response.find("```", start)
        if end != -1:
            return response[start:end].strip()
    elif "```" in response:
        # 处理没有json标识的代码块
        # Handle code blocks without json identifier
        start = response.find("```") + 3
        end = response.find("```", start)
        if end != -1:
            return response[start:end].strip()

    # 如果没有代码块，直接返回原内容
    # If no code block, return original content
    return response


def ask_llm_label(client, model: str, emotion: str, text: str,
                  max_retries=4, backoff=1.8) -> Dict[str, Any]:
    """
    调用 GPT-4o-mini 打标；无 KEY 或错误则返回未标注
    Call GPT-4o-mini for labeling; return unlabeled if no KEY or error
    """
    for i in range(max_retries):
        try:
            user_content = USER_TMPL_LBL.format(emotion=emotion, text=text)
            try:
                resp = client.chat.completions.create(
                    model=model,
                    messages=[
                        {"role": "system", "content": SYSTEM_LBL},
                        {"role": "user",   "content": user_content}
                    ],
                )
            except Exception as api_error:
                if i == max_retries - 1:
                    return {"match": 0, "reason": f"api-error:{type(api_error).__name__}"}
                time.sleep(backoff ** i)
                continue

            # 安全地获取响应内容
            # Safely get response content
            try:
                choice = resp.choices[0]
                message = choice.message
                content = message.content
                out = (content or "").strip()
            except (KeyError, IndexError, AttributeError) as ke:
                return {"match": 0, "reason": f"response-structure-error: {type(ke).__name__}"}

            js = extract_json_from_response(out)
            try:
                j = json.loads(js)
                if "match" not in j: j = {"match": 0, "reason": "invalid-json"}
                if "reason" not in j: j["reason"] = "no-reason-provided"
                return j
            except json.JSONDecodeError as je:
                return {"match": 0, "reason": f"json-decode-error: {str(je)}"}
        except Exception as e:
            if i == max_retries - 1:
                return {"match": 0, "reason": f"error:{type(e).__name__}"}
            time.sleep(backoff ** i)

    return {"match": 0, "reason": "max-retries-exceeded"}


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--input_path", type=str, default=None,
                       help="输入数据路径 Input data path，如 outputs/llama32_3b/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl")
    parser.add_argument("--both", action="store_true",
                       help="处理sev和test_set两个数据集 Process both sev and test_set datasets")
    parser.add_argument("--model_name", type=str, default="llama32_3b",
                       help="模型文件夹名 Model folder name")
    parser.add_argument("--lbl_model", type=str, default="gpt-4o-mini",
                       help="打标模型 Label model")
    parser.add_argument("--skip_if_exists", action="store_true", default=True,
                       help="跳过已打标的项目 Skip already labeled items")
    parser.add_argument("--no_skip", action="store_true",
                       help="重新打标所有项目 Relabel all items")
    args = parser.parse_args()

    # 确定输入文件列表
    # Determine input file list
    if args.both:
        base_path = Path("/content/drive/MyDrive/Various-Model/outputs") / args.model_name / "01_emotion_elicited_generation_prompt_based" / "generated"
        input_paths = [
            base_path / "sev_generated.jsonl",
            base_path / "test_set_generated.jsonl"
        ]
    elif args.input_path:
        input_paths = [Path(args.input_path)]
    else:
        parser.error("必须指定 --input_path 或 --both | Must specify --input_path or --both")
        return

    # 处理每个输入文件
    # Process each input file
    for input_path in input_paths:
        if not input_path.exists():
            print(f"[WARNING] Input file not found: {input_path}, skipping...")
            continue

        # 从输入路径提取 model_name 和 dataset_name
        # Extract model_name and dataset_name from input path
        parts = input_path.parts
        if "outputs" in parts and "01_emotion_elicited_generation_prompt_based" in parts and "generated" in parts:
            outputs_idx = parts.index("outputs")
            model_name = parts[outputs_idx + 1]
            # 从文件名提取dataset_name (例如: sev_generated.jsonl -> sev)
            filename = input_path.stem  # 去掉.jsonl
            if filename.endswith("_generated"):
                dataset_name = filename[:-10]  # 去掉_generated后缀
            else:
                dataset_name = filename
        else:
            print(f"[ERROR] Input path format incorrect: {input_path}")
            print(f"        Expected: outputs/{{model_name}}/01_emotion_elicited_generation_prompt_based/generated/{{dataset_name}}_generated.jsonl")
            continue

        # 构建输出路径
        # Build output path
        out_dir = Path("/content/drive/MyDrive/Various-Model/outputs") / model_name / "01_emotion_elicited_generation_prompt_based" / "labeled" / dataset_name
        out_dir.mkdir(parents=True, exist_ok=True)

        acc_path = out_dir / "accepted.jsonl"
        rej_path = out_dir / "rejected.jsonl"

        # 加载已打标的 keys（用于断点续跑）
        # Load existing keys (for resuming from checkpoint)
        existing_keys = set()
        if args.skip_if_exists and not args.no_skip:
            for path in [acc_path, rej_path]:
                if path.exists():
                    with open(path, "r", encoding="utf-8") as f:
                        for line in f:
                            try:
                                obj = json.loads(line.strip())
                                if "key" in obj:
                                    existing_keys.add(obj["key"])
                            except:
                                continue

        print(f"{'='*70}")
        print(f"Processing dataset: {dataset_name}")
        print(f"Input: {input_path}")
        print(f"Output: {out_dir}")
        print(f"{'='*70}\n")

        total = 0
        skipped = 0
        accepted = 0
        rejected = 0
        start = time.time()

        # 统计字典：按情绪和极性分类
        # Statistics dictionaries: by emotion and valence
        stats_by_emotion = {}  # {emotion: {"total": N, "accepted": M}}
        stats_by_valence = {}  # {valence: {"total": N, "accepted": M}}

        with open(input_path, "r", encoding="utf-8") as fin:
            for line in fin:
                line = line.strip()
                if not line: continue

                try:
                    item = json.loads(line)
                except json.JSONDecodeError:
                    print(f"[WARN] Failed to parse line: {line[:100]}...")
                    continue

                key = item.get("key", "unknown")

                # 断点续跑检查
                # Checkpoint resuming check
                if key in existing_keys:
                    skipped += 1
                    if skipped % 50 == 0:
                        print(f"[SKIP] {skipped} items skipped so far... (last: {key})")
                    continue

                emotion = item.get("emotion", "")
                valence = item.get("valence", "")
                gen_text = item.get("gen_text", "")

                # GPT 打标
                # GPT labeling
                label = {"match": 0, "reason": "empty-text"}
                if isinstance(gen_text, str) and gen_text:
                    label = ask_llm_label(client, args.lbl_model, emotion, gen_text)

                # 添加打标结果和打标时间
                # Add labeling result and timestamp
                item["judge"] = label
                item["label_time"] = int(time.time())

                # 根据打标结果保存
                # Save based on labeling result
                match_score = int(label.get("match", 0))
                if match_score == 1:
                    output_path = acc_path
                    accepted += 1
                    category = "accepted"
                else:
                    output_path = rej_path
                    rejected += 1
                    category = "rejected"

                with open(output_path, "a", encoding="utf-8") as fout:
                    fout.write(json.dumps(item, ensure_ascii=False) + "\n")

                # 更新统计
                # Update statistics
                if emotion:
                    if emotion not in stats_by_emotion:
                        stats_by_emotion[emotion] = {"total": 0, "accepted": 0}
                    stats_by_emotion[emotion]["total"] += 1
                    stats_by_emotion[emotion]["accepted"] += match_score

                if valence:
                    if valence not in stats_by_valence:
                        stats_by_valence[valence] = {"total": 0, "accepted": 0}
                    stats_by_valence[valence]["total"] += 1
                    stats_by_valence[valence]["accepted"] += match_score

                total += 1
                if total % 10 == 0:
                    el = time.time() - start
                    rate = total / el if el > 0 else 0
                    print(f"[progress] labeled={total} (acc={accepted}, rej={rejected}) | last={key} [{category}] | {el:.1f}s | {rate:.2f} items/s")

        elapsed = time.time() - start
        print(f"\n[OK] {dataset_name} completed. Labeled {total} items, skipped {skipped} items.")
        print(f"     Accepted: {accepted} | Rejected: {rejected}")
        print(f"     Time: {elapsed:.1f}s | Rate: {total/elapsed:.2f} items/s")
        print(f"     Output:")
        print(f"       - {acc_path}")
        print(f"       - {rej_path}")

        # ===== 输出统计信息 =====
        # ===== Output statistics =====
        print("\n" + "="*60)
        print(f"📊 ACCURACY STATISTICS - {dataset_name.upper()}")
        print("="*60)

        # 总体正确率
        # Overall accuracy
        overall_acc = (accepted / total * 100) if total > 0 else 0
        print(f"\n🎯 Overall Accuracy: {accepted}/{total} = {overall_acc:.2f}%")

        # 按情绪统计
        # Statistics by emotion
        print(f"\n📈 Accuracy by Emotion:")
        print("-" * 60)
        print(f"{'Emotion':<15} {'Accepted':<12} {'Total':<10} {'Accuracy':<12}")
        print("-" * 60)

        emotions_sorted = sorted(stats_by_emotion.items())
        for emotion, stats in emotions_sorted:
            acc_count = stats["accepted"]
            tot_count = stats["total"]
            acc_rate = (acc_count / tot_count * 100) if tot_count > 0 else 0
            print(f"{emotion:<15} {acc_count:<12} {tot_count:<10} {acc_rate:>6.2f}%")

        # 按极性统计
        # Statistics by valence
        print(f"\n📉 Accuracy by Valence:")
        print("-" * 60)
        print(f"{'Valence':<15} {'Accepted':<12} {'Total':<10} {'Accuracy':<12}")
        print("-" * 60)

        valences_sorted = sorted(stats_by_valence.items())
        for valence, stats in valences_sorted:
            acc_count = stats["accepted"]
            tot_count = stats["total"]
            acc_rate = (acc_count / tot_count * 100) if tot_count > 0 else 0
            print(f"{valence:<15} {acc_count:<12} {tot_count:<10} {acc_rate:>6.2f}%")

        print("="*60 + "\n")


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# Processing dataset: sev
# Input: /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl
# Output: /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled/sev
# ======================================================================
#
# [progress] labeled=10 (acc=10, rej=0) | last=work_00__neutral__fear [accepted] | 14.3s | 0.70 items/s
# [progress] labeled=20 (acc=20, rej=0) | last=work_01__positive__sadness [accepted] | 26.3s | 0.76 items/s
# [progress] labeled=30 (acc=30, rej=0) | last=work_01__neutral__disgust [accepted] | 36.9s | 0.81 items/s
# [progress] labeled=40 (acc=39, rej=1) | last=work_02__positive__fear [accepted] | 54.3s | 0.74 items/s
# [progress] labeled=50 (acc=49, rej=1) | last=work_02__negative__sadness [accepted] | 69.5s | 0.72 items/s
# [progress] labeled=60 (acc=59, rej=1) | last=work_03__positive__disgust [accepted] | 79.3s | 0.76 items/s
# [progress] labeled=70 (acc=69, rej=1) | last=work_03__negative__fear [accepted] | 92.2s | 0.76 items/s
# [progress] labeled=80 (acc=78, rej=2) | last=work_04__neutral__sadness [accepted] | 105.0s | 0.76 items/s
# [progress] labeled=90 (acc=87, rej=3) | last=work_04__negative__disgust [accepted] | 114.7s | 0.78 items/s
# [progress] labeled=100 (acc=97, rej=3) | last=work_05__neutral__fear [accepted] | 124.8s | 0.80 items/s
# [progress] labeled=110 (acc=107, rej=3) | last=work_06__positive__sadness [accepted] | 135.1s | 0.81 items/s
# [progress] labeled=120 (acc=117, rej=3) | last=work_06__neutral__disgust [accepted] | 144.2s | 0.83 items/s
# [progress] labeled=130 (acc=127, rej=3) | last=work_07__positive__fear [accepted] | 154.5s | 0.84 items/s
# [progress] labeled=140 (acc=136, rej=4) | last=work_07__negative__sadness [accepted] | 166.8s | 0.84 items/s
# [progress] labeled=150 (acc=145, rej=5) | last=work_08__positive__disgust [accepted] | 177.3s | 0.85 items/s
# [progress] labeled=160 (acc=155, rej=5) | last=work_08__negative__fear [accepted] | 189.4s | 0.84 items/s
# [progress] labeled=170 (acc=165, rej=5) | last=work_09__neutral__sadness [accepted] | 199.5s | 0.85 items/s
# [progress] labeled=180 (acc=174, rej=6) | last=work_09__negative__disgust [accepted] | 210.2s | 0.86 items/s
# [progress] labeled=190 (acc=184, rej=6) | last=work_10__neutral__fear [accepted] | 220.5s | 0.86 items/s
# [progress] labeled=200 (acc=194, rej=6) | last=work_11__positive__sadness [accepted] | 230.3s | 0.87 items/s
# [progress] labeled=210 (acc=204, rej=6) | last=work_11__neutral__disgust [accepted] | 240.4s | 0.87 items/s
# [progress] labeled=220 (acc=214, rej=6) | last=work_12__positive__fear [accepted] | 251.0s | 0.88 items/s
# [progress] labeled=230 (acc=224, rej=6) | last=work_12__negative__sadness [accepted] | 260.5s | 0.88 items/s
# [progress] labeled=240 (acc=234, rej=6) | last=work_13__positive__disgust [accepted] | 269.6s | 0.89 items/s
# [progress] labeled=250 (acc=244, rej=6) | last=work_13__negative__fear [accepted] | 280.1s | 0.89 items/s
# [progress] labeled=260 (acc=254, rej=6) | last=work_14__neutral__sadness [accepted] | 291.5s | 0.89 items/s
# [progress] labeled=270 (acc=263, rej=7) | last=work_14__negative__disgust [accepted] | 300.0s | 0.90 items/s
# [progress] labeled=280 (acc=273, rej=7) | last=work_15__neutral__fear [accepted] | 310.1s | 0.90 items/s
# [progress] labeled=290 (acc=282, rej=8) | last=work_16__positive__sadness [accepted] | 320.5s | 0.90 items/s
# [progress] labeled=300 (acc=292, rej=8) | last=work_16__neutral__disgust [accepted] | 330.8s | 0.91 items/s
# [progress] labeled=310 (acc=301, rej=9) | last=work_17__positive__fear [accepted] | 341.5s | 0.91 items/s
# [progress] labeled=320 (acc=311, rej=9) | last=work_17__negative__sadness [accepted] | 351.4s | 0.91 items/s
# [progress] labeled=330 (acc=321, rej=9) | last=work_18__positive__disgust [accepted] | 360.8s | 0.91 items/s
# [progress] labeled=340 (acc=331, rej=9) | last=work_18__negative__fear [accepted] | 370.7s | 0.92 items/s
# [progress] labeled=350 (acc=341, rej=9) | last=work_19__neutral__sadness [accepted] | 381.6s | 0.92 items/s
# [progress] labeled=360 (acc=351, rej=9) | last=work_19__negative__disgust [accepted] | 393.7s | 0.91 items/s
# [progress] labeled=370 (acc=361, rej=9) | last=school_00__neutral__fear [accepted] | 403.2s | 0.92 items/s
# [progress] labeled=380 (acc=370, rej=10) | last=school_01__positive__sadness [accepted] | 413.0s | 0.92 items/s
# [progress] labeled=390 (acc=380, rej=10) | last=school_01__neutral__disgust [accepted] | 421.0s | 0.93 items/s
# [progress] labeled=400 (acc=389, rej=11) | last=school_02__positive__fear [accepted] | 429.7s | 0.93 items/s
# [progress] labeled=410 (acc=399, rej=11) | last=school_02__negative__sadness [accepted] | 440.2s | 0.93 items/s
# [progress] labeled=420 (acc=407, rej=13) | last=school_03__positive__disgust [accepted] | 450.2s | 0.93 items/s
# [progress] labeled=430 (acc=417, rej=13) | last=school_03__negative__fear [accepted] | 457.5s | 0.94 items/s
# [progress] labeled=440 (acc=426, rej=14) | last=school_04__neutral__sadness [accepted] | 467.4s | 0.94 items/s
# [progress] labeled=450 (acc=436, rej=14) | last=school_04__negative__disgust [accepted] | 477.3s | 0.94 items/s
# [progress] labeled=460 (acc=446, rej=14) | last=school_05__neutral__fear [accepted] | 486.8s | 0.94 items/s
# [progress] labeled=470 (acc=455, rej=15) | last=school_06__positive__sadness [accepted] | 496.2s | 0.95 items/s
# [progress] labeled=480 (acc=464, rej=16) | last=school_06__neutral__disgust [accepted] | 507.9s | 0.95 items/s
# [progress] labeled=490 (acc=474, rej=16) | last=school_07__positive__fear [accepted] | 517.4s | 0.95 items/s
# [progress] labeled=500 (acc=484, rej=16) | last=school_07__negative__sadness [accepted] | 527.4s | 0.95 items/s
# [progress] labeled=510 (acc=494, rej=16) | last=school_08__positive__disgust [accepted] | 537.6s | 0.95 items/s
# [progress] labeled=520 (acc=504, rej=16) | last=school_08__negative__fear [accepted] | 547.9s | 0.95 items/s
# [progress] labeled=530 (acc=513, rej=17) | last=school_09__neutral__sadness [accepted] | 558.0s | 0.95 items/s
# [progress] labeled=540 (acc=523, rej=17) | last=school_09__negative__disgust [accepted] | 573.0s | 0.94 items/s
# [progress] labeled=550 (acc=533, rej=17) | last=school_10__neutral__fear [accepted] | 583.8s | 0.94 items/s
# [progress] labeled=560 (acc=542, rej=18) | last=school_11__positive__sadness [accepted] | 593.7s | 0.94 items/s
# [progress] labeled=570 (acc=552, rej=18) | last=school_11__neutral__disgust [accepted] | 603.4s | 0.94 items/s
# [progress] labeled=580 (acc=562, rej=18) | last=school_12__positive__fear [accepted] | 619.2s | 0.94 items/s
# [progress] labeled=590 (acc=571, rej=19) | last=school_12__negative__sadness [accepted] | 630.0s | 0.94 items/s
# [progress] labeled=600 (acc=580, rej=20) | last=school_13__positive__disgust [accepted] | 639.6s | 0.94 items/s
# [progress] labeled=610 (acc=590, rej=20) | last=school_13__negative__fear [accepted] | 650.6s | 0.94 items/s
# [progress] labeled=620 (acc=599, rej=21) | last=school_14__neutral__sadness [accepted] | 659.2s | 0.94 items/s
# [progress] labeled=630 (acc=608, rej=22) | last=school_14__negative__disgust [accepted] | 667.7s | 0.94 items/s
# [progress] labeled=640 (acc=618, rej=22) | last=school_15__neutral__fear [accepted] | 679.1s | 0.94 items/s
# [progress] labeled=650 (acc=627, rej=23) | last=school_16__positive__sadness [accepted] | 689.2s | 0.94 items/s
# [progress] labeled=660 (acc=637, rej=23) | last=school_16__neutral__disgust [accepted] | 700.2s | 0.94 items/s
# [progress] labeled=670 (acc=646, rej=24) | last=school_17__positive__fear [accepted] | 709.9s | 0.94 items/s
# [progress] labeled=680 (acc=655, rej=25) | last=school_17__negative__sadness [accepted] | 719.1s | 0.95 items/s
# [progress] labeled=690 (acc=664, rej=26) | last=school_18__positive__disgust [accepted] | 728.6s | 0.95 items/s
# [progress] labeled=700 (acc=674, rej=26) | last=school_18__negative__fear [accepted] | 738.0s | 0.95 items/s
# [progress] labeled=710 (acc=683, rej=27) | last=school_19__neutral__sadness [accepted] | 746.7s | 0.95 items/s
# [progress] labeled=720 (acc=692, rej=28) | last=school_19__negative__disgust [accepted] | 755.2s | 0.95 items/s
# [progress] labeled=730 (acc=701, rej=29) | last=relation_00__neutral__fear [accepted] | 765.1s | 0.95 items/s
# [progress] labeled=740 (acc=709, rej=31) | last=relation_01__positive__sadness [accepted] | 776.6s | 0.95 items/s
# [progress] labeled=750 (acc=717, rej=33) | last=relation_01__neutral__disgust [accepted] | 786.1s | 0.95 items/s
# [progress] labeled=760 (acc=726, rej=34) | last=relation_02__positive__fear [accepted] | 797.0s | 0.95 items/s
# [progress] labeled=770 (acc=736, rej=34) | last=relation_02__negative__sadness [accepted] | 807.9s | 0.95 items/s
# [progress] labeled=780 (acc=746, rej=34) | last=relation_03__positive__disgust [accepted] | 818.7s | 0.95 items/s
# [progress] labeled=790 (acc=756, rej=34) | last=relation_03__negative__fear [accepted] | 834.0s | 0.95 items/s
# [progress] labeled=800 (acc=765, rej=35) | last=relation_04__neutral__sadness [accepted] | 848.1s | 0.94 items/s
# [progress] labeled=810 (acc=774, rej=36) | last=relation_04__negative__disgust [accepted] | 859.3s | 0.94 items/s
# [progress] labeled=820 (acc=784, rej=36) | last=relation_05__neutral__fear [accepted] | 869.3s | 0.94 items/s
# [progress] labeled=830 (acc=794, rej=36) | last=relation_06__positive__sadness [accepted] | 878.5s | 0.94 items/s
# [progress] labeled=840 (acc=802, rej=38) | last=relation_06__neutral__disgust [accepted] | 887.9s | 0.95 items/s
# [progress] labeled=850 (acc=810, rej=40) | last=relation_07__positive__fear [accepted] | 897.5s | 0.95 items/s
# [progress] labeled=860 (acc=820, rej=40) | last=relation_07__negative__sadness [accepted] | 908.4s | 0.95 items/s
# [progress] labeled=870 (acc=828, rej=42) | last=relation_08__positive__disgust [accepted] | 918.4s | 0.95 items/s
# [progress] labeled=880 (acc=837, rej=43) | last=relation_08__negative__fear [accepted] | 931.3s | 0.94 items/s
# [progress] labeled=890 (acc=847, rej=43) | last=relation_09__neutral__sadness [accepted] | 943.9s | 0.94 items/s
# [progress] labeled=900 (acc=856, rej=44) | last=relation_09__negative__disgust [accepted] | 954.9s | 0.94 items/s
# [progress] labeled=910 (acc=866, rej=44) | last=relation_10__neutral__fear [accepted] | 965.6s | 0.94 items/s
# [progress] labeled=920 (acc=876, rej=44) | last=relation_11__positive__sadness [accepted] | 976.7s | 0.94 items/s
# [progress] labeled=930 (acc=886, rej=44) | last=relation_11__neutral__disgust [accepted] | 986.0s | 0.94 items/s
# [progress] labeled=940 (acc=895, rej=45) | last=relation_12__positive__fear [accepted] | 997.1s | 0.94 items/s
# [progress] labeled=950 (acc=905, rej=45) | last=relation_12__negative__sadness [accepted] | 1007.6s | 0.94 items/s
# [progress] labeled=960 (acc=915, rej=45) | last=relation_13__positive__disgust [accepted] | 1020.9s | 0.94 items/s
# [progress] labeled=970 (acc=925, rej=45) | last=relation_13__negative__fear [accepted] | 1031.5s | 0.94 items/s
# [progress] labeled=980 (acc=935, rej=45) | last=relation_14__neutral__sadness [accepted] | 1044.2s | 0.94 items/s
# [progress] labeled=990 (acc=944, rej=46) | last=relation_14__negative__disgust [accepted] | 1054.2s | 0.94 items/s
# [progress] labeled=1000 (acc=954, rej=46) | last=relation_15__neutral__fear [accepted] | 1064.3s | 0.94 items/s
# [progress] labeled=1010 (acc=963, rej=47) | last=relation_16__positive__sadness [accepted] | 1073.4s | 0.94 items/s
# [progress] labeled=1020 (acc=973, rej=47) | last=relation_16__neutral__disgust [accepted] | 1083.6s | 0.94 items/s
# [progress] labeled=1030 (acc=983, rej=47) | last=relation_17__positive__fear [accepted] | 1093.8s | 0.94 items/s
# [progress] labeled=1040 (acc=992, rej=48) | last=relation_17__negative__sadness [accepted] | 1104.7s | 0.94 items/s
# [progress] labeled=1050 (acc=1001, rej=49) | last=relation_18__positive__disgust [accepted] | 1117.0s | 0.94 items/s
# [progress] labeled=1060 (acc=1011, rej=49) | last=relation_18__negative__fear [accepted] | 1126.5s | 0.94 items/s
# [progress] labeled=1070 (acc=1020, rej=50) | last=relation_19__neutral__sadness [accepted] | 1137.5s | 0.94 items/s
# [progress] labeled=1080 (acc=1030, rej=50) | last=relation_19__negative__disgust [accepted] | 1148.0s | 0.94 items/s
# [progress] labeled=1090 (acc=1040, rej=50) | last=shopping_00__neutral__fear [accepted] | 1158.2s | 0.94 items/s
# [progress] labeled=1100 (acc=1048, rej=52) | last=shopping_01__positive__sadness [accepted] | 1167.6s | 0.94 items/s
# [progress] labeled=1110 (acc=1058, rej=52) | last=shopping_01__neutral__disgust [accepted] | 1177.4s | 0.94 items/s
# [progress] labeled=1120 (acc=1067, rej=53) | last=shopping_02__positive__fear [accepted] | 1185.8s | 0.94 items/s
# [progress] labeled=1130 (acc=1077, rej=53) | last=shopping_02__negative__sadness [accepted] | 1197.0s | 0.94 items/s
# [progress] labeled=1140 (acc=1086, rej=54) | last=shopping_03__positive__disgust [accepted] | 1207.2s | 0.94 items/s
# [progress] labeled=1150 (acc=1096, rej=54) | last=shopping_03__negative__fear [accepted] | 1219.6s | 0.94 items/s
# [progress] labeled=1160 (acc=1105, rej=55) | last=shopping_04__neutral__sadness [accepted] | 1229.4s | 0.94 items/s
# [progress] labeled=1170 (acc=1113, rej=57) | last=shopping_04__negative__disgust [accepted] | 1240.7s | 0.94 items/s
# [progress] labeled=1180 (acc=1123, rej=57) | last=shopping_05__neutral__fear [accepted] | 1250.7s | 0.94 items/s
# [progress] labeled=1190 (acc=1131, rej=59) | last=shopping_06__positive__sadness [accepted] | 1262.2s | 0.94 items/s
# [progress] labeled=1200 (acc=1141, rej=59) | last=shopping_06__neutral__disgust [accepted] | 1273.0s | 0.94 items/s
# [progress] labeled=1210 (acc=1149, rej=61) | last=shopping_07__positive__fear [accepted] | 1283.6s | 0.94 items/s
# [progress] labeled=1220 (acc=1159, rej=61) | last=shopping_07__negative__sadness [accepted] | 1293.2s | 0.94 items/s
# [progress] labeled=1230 (acc=1169, rej=61) | last=shopping_08__positive__disgust [accepted] | 1304.9s | 0.94 items/s
# [progress] labeled=1240 (acc=1179, rej=61) | last=shopping_08__negative__fear [accepted] | 1315.3s | 0.94 items/s
# [progress] labeled=1250 (acc=1188, rej=62) | last=shopping_09__neutral__sadness [accepted] | 1325.6s | 0.94 items/s
# [progress] labeled=1260 (acc=1197, rej=63) | last=shopping_09__negative__disgust [accepted] | 1336.6s | 0.94 items/s
# [progress] labeled=1270 (acc=1207, rej=63) | last=shopping_10__neutral__fear [accepted] | 1348.5s | 0.94 items/s
# [progress] labeled=1280 (acc=1216, rej=64) | last=shopping_11__positive__sadness [accepted] | 1358.8s | 0.94 items/s
# [progress] labeled=1290 (acc=1226, rej=64) | last=shopping_11__neutral__disgust [accepted] | 1368.4s | 0.94 items/s
# [progress] labeled=1300 (acc=1235, rej=65) | last=shopping_12__positive__fear [accepted] | 1380.0s | 0.94 items/s
# [progress] labeled=1310 (acc=1245, rej=65) | last=shopping_12__negative__sadness [accepted] | 1389.9s | 0.94 items/s
# [progress] labeled=1320 (acc=1254, rej=66) | last=shopping_13__positive__disgust [accepted] | 1404.1s | 0.94 items/s
# [progress] labeled=1330 (acc=1264, rej=66) | last=shopping_13__negative__fear [accepted] | 1413.3s | 0.94 items/s
# [progress] labeled=1340 (acc=1273, rej=67) | last=shopping_14__neutral__sadness [accepted] | 1423.2s | 0.94 items/s
# [progress] labeled=1350 (acc=1282, rej=68) | last=shopping_14__negative__disgust [accepted] | 1433.5s | 0.94 items/s
# [progress] labeled=1360 (acc=1291, rej=69) | last=shopping_15__neutral__fear [rejected] | 1442.1s | 0.94 items/s
# [progress] labeled=1370 (acc=1300, rej=70) | last=shopping_16__positive__sadness [accepted] | 1453.5s | 0.94 items/s
# [progress] labeled=1380 (acc=1310, rej=70) | last=shopping_16__neutral__disgust [accepted] | 1463.4s | 0.94 items/s
# [progress] labeled=1390 (acc=1319, rej=71) | last=shopping_17__positive__fear [accepted] | 1473.7s | 0.94 items/s
# [progress] labeled=1400 (acc=1329, rej=71) | last=shopping_17__negative__sadness [accepted] | 1483.3s | 0.94 items/s
# [progress] labeled=1410 (acc=1339, rej=71) | last=shopping_18__positive__disgust [accepted] | 1493.4s | 0.94 items/s
# [progress] labeled=1420 (acc=1349, rej=71) | last=shopping_18__negative__fear [accepted] | 1503.8s | 0.94 items/s
# [progress] labeled=1430 (acc=1356, rej=74) | last=shopping_19__neutral__sadness [rejected] | 1514.7s | 0.94 items/s
# [progress] labeled=1440 (acc=1366, rej=74) | last=shopping_19__negative__disgust [accepted] | 1524.9s | 0.94 items/s
# [progress] labeled=1450 (acc=1376, rej=74) | last=administration_00__neutral__fear [accepted] | 1535.7s | 0.94 items/s
# [progress] labeled=1460 (acc=1385, rej=75) | last=administration_01__positive__sadness [accepted] | 1545.2s | 0.94 items/s
# [progress] labeled=1470 (acc=1394, rej=76) | last=administration_01__neutral__disgust [accepted] | 1555.3s | 0.95 items/s
# [progress] labeled=1480 (acc=1404, rej=76) | last=administration_02__positive__fear [accepted] | 1567.1s | 0.94 items/s
# [progress] labeled=1490 (acc=1414, rej=76) | last=administration_02__negative__sadness [accepted] | 1578.6s | 0.94 items/s
# [progress] labeled=1500 (acc=1424, rej=76) | last=administration_03__positive__disgust [accepted] | 1590.6s | 0.94 items/s
# [progress] labeled=1510 (acc=1433, rej=77) | last=administration_03__negative__fear [accepted] | 1601.5s | 0.94 items/s
# [progress] labeled=1520 (acc=1442, rej=78) | last=administration_04__neutral__sadness [accepted] | 1611.8s | 0.94 items/s
# [progress] labeled=1530 (acc=1451, rej=79) | last=administration_04__negative__disgust [accepted] | 1621.4s | 0.94 items/s
# [progress] labeled=1540 (acc=1461, rej=79) | last=administration_05__neutral__fear [accepted] | 1631.1s | 0.94 items/s
# [progress] labeled=1550 (acc=1470, rej=80) | last=administration_06__positive__sadness [accepted] | 1640.2s | 0.94 items/s
# [progress] labeled=1560 (acc=1480, rej=80) | last=administration_06__neutral__disgust [accepted] | 1653.1s | 0.94 items/s
# [progress] labeled=1570 (acc=1489, rej=81) | last=administration_07__positive__fear [accepted] | 1665.3s | 0.94 items/s
# [progress] labeled=1580 (acc=1497, rej=83) | last=administration_07__negative__sadness [accepted] | 1675.3s | 0.94 items/s
# [progress] labeled=1590 (acc=1507, rej=83) | last=administration_08__positive__disgust [accepted] | 1685.9s | 0.94 items/s
# [progress] labeled=1600 (acc=1517, rej=83) | last=administration_08__negative__fear [accepted] | 1696.5s | 0.94 items/s
# [progress] labeled=1610 (acc=1527, rej=83) | last=administration_09__neutral__sadness [accepted] | 1708.6s | 0.94 items/s
# [progress] labeled=1620 (acc=1537, rej=83) | last=administration_09__negative__disgust [accepted] | 1720.4s | 0.94 items/s
# [progress] labeled=1630 (acc=1547, rej=83) | last=administration_10__neutral__fear [accepted] | 1730.1s | 0.94 items/s
# [progress] labeled=1640 (acc=1557, rej=83) | last=administration_11__positive__sadness [accepted] | 1740.7s | 0.94 items/s
# [progress] labeled=1650 (acc=1567, rej=83) | last=administration_11__neutral__disgust [accepted] | 1749.7s | 0.94 items/s
# [progress] labeled=1660 (acc=1576, rej=84) | last=administration_12__positive__fear [accepted] | 1759.9s | 0.94 items/s
# [progress] labeled=1670 (acc=1586, rej=84) | last=administration_12__negative__sadness [accepted] | 1770.0s | 0.94 items/s
# [progress] labeled=1680 (acc=1595, rej=85) | last=administration_13__positive__disgust [accepted] | 1781.2s | 0.94 items/s
# [progress] labeled=1690 (acc=1605, rej=85) | last=administration_13__negative__fear [accepted] | 1789.8s | 0.94 items/s
# [progress] labeled=1700 (acc=1614, rej=86) | last=administration_14__neutral__sadness [accepted] | 1799.8s | 0.94 items/s
# [progress] labeled=1710 (acc=1623, rej=87) | last=administration_14__negative__disgust [accepted] | 1810.7s | 0.94 items/s
# [progress] labeled=1720 (acc=1633, rej=87) | last=administration_15__neutral__fear [accepted] | 1820.4s | 0.94 items/s
# [progress] labeled=1730 (acc=1643, rej=87) | last=administration_16__positive__sadness [accepted] | 1829.3s | 0.95 items/s
# [progress] labeled=1740 (acc=1653, rej=87) | last=administration_16__neutral__disgust [accepted] | 1838.7s | 0.95 items/s
# [progress] labeled=1750 (acc=1663, rej=87) | last=administration_17__positive__fear [accepted] | 1848.0s | 0.95 items/s
# [progress] labeled=1760 (acc=1673, rej=87) | last=administration_17__negative__sadness [accepted] | 1857.5s | 0.95 items/s
# [progress] labeled=1770 (acc=1682, rej=88) | last=administration_18__positive__disgust [accepted] | 1865.9s | 0.95 items/s
# [progress] labeled=1780 (acc=1692, rej=88) | last=administration_18__negative__fear [accepted] | 1876.2s | 0.95 items/s
# [progress] labeled=1790 (acc=1701, rej=89) | last=administration_19__neutral__sadness [accepted] | 1887.0s | 0.95 items/s
# [progress] labeled=1800 (acc=1711, rej=89) | last=administration_19__negative__disgust [accepted] | 1898.9s | 0.95 items/s
# [progress] labeled=1810 (acc=1721, rej=89) | last=health_00__neutral__fear [accepted] | 1910.8s | 0.95 items/s
# [progress] labeled=1820 (acc=1730, rej=90) | last=health_01__positive__sadness [accepted] | 1921.9s | 0.95 items/s
# [progress] labeled=1830 (acc=1740, rej=90) | last=health_01__neutral__disgust [accepted] | 1932.3s | 0.95 items/s
# [progress] labeled=1840 (acc=1750, rej=90) | last=health_02__positive__fear [accepted] | 1943.3s | 0.95 items/s
# [progress] labeled=1850 (acc=1759, rej=91) | last=health_02__negative__sadness [accepted] | 1953.7s | 0.95 items/s
# [progress] labeled=1860 (acc=1768, rej=92) | last=health_03__positive__disgust [accepted] | 1964.9s | 0.95 items/s
# [progress] labeled=1870 (acc=1778, rej=92) | last=health_03__negative__fear [accepted] | 1975.4s | 0.95 items/s
# [progress] labeled=1880 (acc=1786, rej=94) | last=health_04__neutral__sadness [accepted] | 1986.2s | 0.95 items/s
# [progress] labeled=1890 (acc=1796, rej=94) | last=health_04__negative__disgust [accepted] | 1996.4s | 0.95 items/s
# [progress] labeled=1900 (acc=1805, rej=95) | last=health_05__neutral__fear [accepted] | 2006.0s | 0.95 items/s
# [progress] labeled=1910 (acc=1815, rej=95) | last=health_06__positive__sadness [accepted] | 2016.7s | 0.95 items/s
# [progress] labeled=1920 (acc=1824, rej=96) | last=health_06__neutral__disgust [accepted] | 2026.7s | 0.95 items/s
# [progress] labeled=1930 (acc=1833, rej=97) | last=health_07__positive__fear [accepted] | 2037.2s | 0.95 items/s
# [progress] labeled=1940 (acc=1843, rej=97) | last=health_07__negative__sadness [accepted] | 2048.6s | 0.95 items/s
# [progress] labeled=1950 (acc=1853, rej=97) | last=health_08__positive__disgust [accepted] | 2059.6s | 0.95 items/s
# [progress] labeled=1960 (acc=1862, rej=98) | last=health_08__negative__fear [accepted] | 2070.3s | 0.95 items/s
# [progress] labeled=1970 (acc=1871, rej=99) | last=health_09__neutral__sadness [accepted] | 2080.2s | 0.95 items/s
# [progress] labeled=1980 (acc=1879, rej=101) | last=health_09__negative__disgust [accepted] | 2089.1s | 0.95 items/s
# [progress] labeled=1990 (acc=1889, rej=101) | last=health_10__neutral__fear [accepted] | 2099.2s | 0.95 items/s
# [progress] labeled=2000 (acc=1898, rej=102) | last=health_11__positive__sadness [accepted] | 2109.0s | 0.95 items/s
# [progress] labeled=2010 (acc=1908, rej=102) | last=health_11__neutral__disgust [accepted] | 2118.9s | 0.95 items/s
# [progress] labeled=2020 (acc=1918, rej=102) | last=health_12__positive__fear [accepted] | 2128.6s | 0.95 items/s
# [progress] labeled=2030 (acc=1927, rej=103) | last=health_12__negative__sadness [accepted] | 2137.2s | 0.95 items/s
# [progress] labeled=2040 (acc=1936, rej=104) | last=health_13__positive__disgust [accepted] | 2145.9s | 0.95 items/s
# [progress] labeled=2050 (acc=1946, rej=104) | last=health_13__negative__fear [accepted] | 2154.1s | 0.95 items/s
# [progress] labeled=2060 (acc=1955, rej=105) | last=health_14__neutral__sadness [accepted] | 2164.2s | 0.95 items/s
# [progress] labeled=2070 (acc=1963, rej=107) | last=health_14__negative__disgust [accepted] | 2172.9s | 0.95 items/s
# [progress] labeled=2080 (acc=1973, rej=107) | last=health_15__neutral__fear [accepted] | 2182.8s | 0.95 items/s
# [progress] labeled=2090 (acc=1983, rej=107) | last=health_16__positive__sadness [accepted] | 2191.3s | 0.95 items/s
# [progress] labeled=2100 (acc=1993, rej=107) | last=health_16__neutral__disgust [accepted] | 2200.2s | 0.95 items/s
# [progress] labeled=2110 (acc=2002, rej=108) | last=health_17__positive__fear [accepted] | 2209.5s | 0.95 items/s
# [progress] labeled=2120 (acc=2012, rej=108) | last=health_17__negative__sadness [accepted] | 2218.6s | 0.96 items/s
# [progress] labeled=2130 (acc=2021, rej=109) | last=health_18__positive__disgust [accepted] | 2228.6s | 0.96 items/s
# [progress] labeled=2140 (acc=2029, rej=111) | last=health_18__negative__fear [accepted] | 2239.1s | 0.96 items/s
# [progress] labeled=2150 (acc=2039, rej=111) | last=health_19__neutral__sadness [accepted] | 2249.4s | 0.96 items/s
# [progress] labeled=2160 (acc=2048, rej=112) | last=health_19__negative__disgust [accepted] | 2260.6s | 0.96 items/s
# [progress] labeled=2170 (acc=2058, rej=112) | last=living_00__neutral__fear [accepted] | 2269.1s | 0.96 items/s
# [progress] labeled=2180 (acc=2067, rej=113) | last=living_01__positive__sadness [accepted] | 2279.0s | 0.96 items/s
# [progress] labeled=2190 (acc=2077, rej=113) | last=living_01__neutral__disgust [accepted] | 2288.8s | 0.96 items/s
# [progress] labeled=2200 (acc=2086, rej=114) | last=living_02__positive__fear [accepted] | 2297.5s | 0.96 items/s
# [progress] labeled=2210 (acc=2096, rej=114) | last=living_02__negative__sadness [accepted] | 2306.9s | 0.96 items/s
# [progress] labeled=2220 (acc=2105, rej=115) | last=living_03__positive__disgust [accepted] | 2317.7s | 0.96 items/s
# [progress] labeled=2230 (acc=2115, rej=115) | last=living_03__negative__fear [accepted] | 2327.0s | 0.96 items/s
# [progress] labeled=2240 (acc=2124, rej=116) | last=living_04__neutral__sadness [accepted] | 2336.5s | 0.96 items/s
# [progress] labeled=2250 (acc=2133, rej=117) | last=living_04__negative__disgust [accepted] | 2346.6s | 0.96 items/s
# [progress] labeled=2260 (acc=2143, rej=117) | last=living_05__neutral__fear [accepted] | 2356.3s | 0.96 items/s
# [progress] labeled=2270 (acc=2153, rej=117) | last=living_06__positive__sadness [accepted] | 2366.4s | 0.96 items/s
# [progress] labeled=2280 (acc=2163, rej=117) | last=living_06__neutral__disgust [accepted] | 2377.3s | 0.96 items/s
# [progress] labeled=2290 (acc=2173, rej=117) | last=living_07__positive__fear [accepted] | 2386.0s | 0.96 items/s
# [progress] labeled=2300 (acc=2182, rej=118) | last=living_07__negative__sadness [accepted] | 2396.1s | 0.96 items/s
# [progress] labeled=2310 (acc=2192, rej=118) | last=living_08__positive__disgust [accepted] | 2405.1s | 0.96 items/s
# [progress] labeled=2320 (acc=2202, rej=118) | last=living_08__negative__fear [accepted] | 2413.7s | 0.96 items/s
# [progress] labeled=2330 (acc=2211, rej=119) | last=living_09__neutral__sadness [accepted] | 2422.1s | 0.96 items/s
# [progress] labeled=2340 (acc=2221, rej=119) | last=living_09__negative__disgust [accepted] | 2431.4s | 0.96 items/s
# [progress] labeled=2350 (acc=2231, rej=119) | last=living_10__neutral__fear [accepted] | 2440.8s | 0.96 items/s
# [progress] labeled=2360 (acc=2240, rej=120) | last=living_11__positive__sadness [accepted] | 2450.8s | 0.96 items/s
# [progress] labeled=2370 (acc=2250, rej=120) | last=living_11__neutral__disgust [accepted] | 2462.3s | 0.96 items/s
# [progress] labeled=2380 (acc=2259, rej=121) | last=living_12__positive__fear [accepted] | 2474.4s | 0.96 items/s
# [progress] labeled=2390 (acc=2269, rej=121) | last=living_12__negative__sadness [accepted] | 2484.2s | 0.96 items/s
# [progress] labeled=2400 (acc=2278, rej=122) | last=living_13__positive__disgust [accepted] | 2493.9s | 0.96 items/s
# [progress] labeled=2410 (acc=2288, rej=122) | last=living_13__negative__fear [accepted] | 2505.9s | 0.96 items/s
# [progress] labeled=2420 (acc=2297, rej=123) | last=living_14__neutral__sadness [accepted] | 2516.8s | 0.96 items/s
# [progress] labeled=2430 (acc=2306, rej=124) | last=living_14__negative__disgust [accepted] | 2526.3s | 0.96 items/s
# [progress] labeled=2440 (acc=2316, rej=124) | last=living_15__neutral__fear [accepted] | 2536.2s | 0.96 items/s
# [progress] labeled=2450 (acc=2326, rej=124) | last=living_16__positive__sadness [accepted] | 2547.9s | 0.96 items/s
# [progress] labeled=2460 (acc=2336, rej=124) | last=living_16__neutral__disgust [accepted] | 2557.1s | 0.96 items/s
# [progress] labeled=2470 (acc=2345, rej=125) | last=living_17__positive__fear [accepted] | 2565.7s | 0.96 items/s
# [progress] labeled=2480 (acc=2355, rej=125) | last=living_17__negative__sadness [accepted] | 2575.3s | 0.96 items/s
# [progress] labeled=2490 (acc=2364, rej=126) | last=living_18__positive__disgust [accepted] | 2584.7s | 0.96 items/s
# [progress] labeled=2500 (acc=2374, rej=126) | last=living_18__negative__fear [accepted] | 2595.2s | 0.96 items/s
# [progress] labeled=2510 (acc=2384, rej=126) | last=living_19__neutral__sadness [accepted] | 2604.7s | 0.96 items/s
# [progress] labeled=2520 (acc=2393, rej=127) | last=living_19__negative__disgust [accepted] | 2614.0s | 0.96 items/s
# [progress] labeled=2530 (acc=2403, rej=127) | last=travel_00__neutral__fear [accepted] | 2623.9s | 0.96 items/s
# [progress] labeled=2540 (acc=2412, rej=128) | last=travel_01__positive__sadness [accepted] | 2634.1s | 0.96 items/s
# [progress] labeled=2550 (acc=2422, rej=128) | last=travel_01__neutral__disgust [accepted] | 2646.1s | 0.96 items/s
# [progress] labeled=2560 (acc=2432, rej=128) | last=travel_02__positive__fear [accepted] | 2656.0s | 0.96 items/s
# [progress] labeled=2570 (acc=2442, rej=128) | last=travel_02__negative__sadness [accepted] | 2667.1s | 0.96 items/s
# [progress] labeled=2580 (acc=2452, rej=128) | last=travel_03__positive__disgust [accepted] | 2677.2s | 0.96 items/s
# [progress] labeled=2590 (acc=2462, rej=128) | last=travel_03__negative__fear [accepted] | 2688.3s | 0.96 items/s
# [progress] labeled=2600 (acc=2470, rej=130) | last=travel_04__neutral__sadness [rejected] | 2697.9s | 0.96 items/s
# [progress] labeled=2610 (acc=2479, rej=131) | last=travel_04__negative__disgust [accepted] | 2707.5s | 0.96 items/s
# [progress] labeled=2620 (acc=2488, rej=132) | last=travel_05__neutral__fear [accepted] | 2718.0s | 0.96 items/s
# [progress] labeled=2630 (acc=2497, rej=133) | last=travel_06__positive__sadness [accepted] | 2726.1s | 0.96 items/s
# [progress] labeled=2640 (acc=2507, rej=133) | last=travel_06__neutral__disgust [accepted] | 2735.2s | 0.97 items/s
# [progress] labeled=2650 (acc=2517, rej=133) | last=travel_07__positive__fear [accepted] | 2744.4s | 0.97 items/s
# [progress] labeled=2660 (acc=2527, rej=133) | last=travel_07__negative__sadness [accepted] | 2754.4s | 0.97 items/s
# [progress] labeled=2670 (acc=2536, rej=134) | last=travel_08__positive__disgust [accepted] | 2763.0s | 0.97 items/s
# [progress] labeled=2680 (acc=2546, rej=134) | last=travel_08__negative__fear [accepted] | 2771.6s | 0.97 items/s
# [progress] labeled=2690 (acc=2555, rej=135) | last=travel_09__neutral__sadness [accepted] | 2780.8s | 0.97 items/s
# [progress] labeled=2700 (acc=2564, rej=136) | last=travel_09__negative__disgust [accepted] | 2790.5s | 0.97 items/s
# [progress] labeled=2710 (acc=2574, rej=136) | last=travel_10__neutral__fear [accepted] | 2800.6s | 0.97 items/s
# [progress] labeled=2720 (acc=2583, rej=137) | last=travel_11__positive__sadness [accepted] | 2809.9s | 0.97 items/s
# [progress] labeled=2730 (acc=2593, rej=137) | last=travel_11__neutral__disgust [accepted] | 2819.6s | 0.97 items/s
# [progress] labeled=2740 (acc=2602, rej=138) | last=travel_12__positive__fear [accepted] | 2827.9s | 0.97 items/s
# [progress] labeled=2750 (acc=2611, rej=139) | last=travel_12__negative__sadness [accepted] | 2838.1s | 0.97 items/s
# [progress] labeled=2760 (acc=2620, rej=140) | last=travel_13__positive__disgust [accepted] | 2848.0s | 0.97 items/s
# [progress] labeled=2770 (acc=2630, rej=140) | last=travel_13__negative__fear [accepted] | 2858.1s | 0.97 items/s
# [progress] labeled=2780 (acc=2639, rej=141) | last=travel_14__neutral__sadness [accepted] | 2868.2s | 0.97 items/s
# [progress] labeled=2790 (acc=2648, rej=142) | last=travel_14__negative__disgust [accepted] | 2877.3s | 0.97 items/s
# [progress] labeled=2800 (acc=2658, rej=142) | last=travel_15__neutral__fear [accepted] | 2886.5s | 0.97 items/s
# [progress] labeled=2810 (acc=2666, rej=144) | last=travel_16__positive__sadness [accepted] | 2895.3s | 0.97 items/s
# [progress] labeled=2820 (acc=2676, rej=144) | last=travel_16__neutral__disgust [accepted] | 2905.9s | 0.97 items/s
# [progress] labeled=2830 (acc=2685, rej=145) | last=travel_17__positive__fear [accepted] | 2916.9s | 0.97 items/s
# [progress] labeled=2840 (acc=2694, rej=146) | last=travel_17__negative__sadness [accepted] | 2926.3s | 0.97 items/s
# [progress] labeled=2850 (acc=2703, rej=147) | last=travel_18__positive__disgust [accepted] | 2937.0s | 0.97 items/s
# [progress] labeled=2860 (acc=2713, rej=147) | last=travel_18__negative__fear [accepted] | 2946.4s | 0.97 items/s
# [progress] labeled=2870 (acc=2722, rej=148) | last=travel_19__neutral__sadness [accepted] | 2956.1s | 0.97 items/s
# [progress] labeled=2880 (acc=2731, rej=149) | last=travel_19__negative__disgust [accepted] | 2965.7s | 0.97 items/s
#
# [OK] sev completed. Labeled 2880 items, skipped 0 items.
#      Accepted: 2731 | Rejected: 149
#      Time: 2965.7s | Rate: 0.97 items/s
#      Output:
#        - /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled/sev/accepted.jsonl
#        - /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled/sev/rejected.jsonl
#
# ============================================================
# 📊 ACCURACY STATISTICS - SEV
# ============================================================
#
# 🎯 Overall Accuracy: 2731/2880 = 94.83%
#
# 📈 Accuracy by Emotion:
# ------------------------------------------------------------
# Emotion         Accepted     Total      Accuracy
# ------------------------------------------------------------
# anger           474          480         98.75%
# disgust         478          480         99.58%
# fear            475          480         98.96%
# happiness       480          480        100.00%
# sadness         475          480         98.96%
# surprise        349          480         72.71%
#
# 📉 Accuracy by Valence:
# ------------------------------------------------------------
# Valence         Accepted     Total      Accuracy
# ------------------------------------------------------------
# negative        858          960         89.38%
# neutral         927          960         96.56%
# positive        946          960         98.54%
# ============================================================

# %%
import sys
sys.argv = [
    "program",
    "--input_dir", "/content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled",
    "--dataset", "sev"
]

# %%
# scripts/01_emotion_elicited_generation_prompt_based/3_generate_accuracy_stats.py
"""
Accuracy Statistics Generation Script

Reads accepted and rejected files from script 2, calculates accuracy by emotion and valence

-  Input: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/labeled/{dataset_name}/{accepted|rejected}.jsonl
-  Output: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/labeled/{dataset_name}/accuracy_stats.json
"""

import json, argparse
from pathlib import Path
from collections import defaultdict


def generate_accuracy_stats(labeled_dir: Path, dataset_name: str):
    """
    Generate accuracy statistics for specified dataset
    """

    dataset_dir = labeled_dir / dataset_name
    accepted_path = dataset_dir / "accepted.jsonl"
    rejected_path = dataset_dir / "rejected.jsonl"
    stats_path = dataset_dir / "accuracy_stats.json"

    if not dataset_dir.exists():
        print(f"[ERROR] Dataset directory not found: {dataset_dir}")
        return None

    # Statistics dictionaries
    stats_by_emotion = defaultdict(lambda: {"total": 0, "accepted": 0, "rejected": 0})
    stats_by_valence = defaultdict(lambda: {"total": 0, "accepted": 0, "rejected": 0})

    total_accepted = 0
    total_rejected = 0

    # Read accepted
    if accepted_path.exists():
        print(f"Reading {accepted_path}...")
        with open(accepted_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    item = json.loads(line)
                    emotion = item.get("emotion", "unknown")
                    valence = item.get("valence", "unknown")

                    stats_by_emotion[emotion]["total"] += 1
                    stats_by_emotion[emotion]["accepted"] += 1

                    stats_by_valence[valence]["total"] += 1
                    stats_by_valence[valence]["accepted"] += 1

                    total_accepted += 1
                except json.JSONDecodeError:
                    continue
    else:
        print(f"[WARNING] Accepted file not found: {accepted_path}")

    # Read rejected
    if rejected_path.exists():
        print(f"Reading {rejected_path}...")
        with open(rejected_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    item = json.loads(line)
                    emotion = item.get("emotion", "unknown")
                    valence = item.get("valence", "unknown")

                    stats_by_emotion[emotion]["total"] += 1
                    stats_by_emotion[emotion]["rejected"] += 1

                    stats_by_valence[valence]["total"] += 1
                    stats_by_valence[valence]["rejected"] += 1

                    total_rejected += 1
                except json.JSONDecodeError:
                    continue
    else:
        print(f"[WARNING] Rejected file not found: {rejected_path}")

    # Calculate accuracy
    for emotion in stats_by_emotion:
        total = stats_by_emotion[emotion]["total"]
        accepted = stats_by_emotion[emotion]["accepted"]
        stats_by_emotion[emotion]["accuracy"] = round(accepted / total * 100, 2) if total > 0 else 0.0

    for valence in stats_by_valence:
        total = stats_by_valence[valence]["total"]
        accepted = stats_by_valence[valence]["accepted"]
        stats_by_valence[valence]["accuracy"] = round(accepted / total * 100, 2) if total > 0 else 0.0

    # Overall statistics
    total_samples = total_accepted + total_rejected
    overall_accuracy = round(total_accepted / total_samples * 100, 2) if total_samples > 0 else 0.0

    # Build statistics result
    stats = {
        "dataset": dataset_name,
        "overall": {
            "total_samples": total_samples,
            "accepted": total_accepted,
            "rejected": total_rejected,
            "accuracy": overall_accuracy
        },
        "by_emotion": dict(stats_by_emotion),
        "by_valence": dict(stats_by_valence)
    }

    # Save statistics file
    with open(stats_path, "w", encoding="utf-8") as f:
        json.dump(stats, f, ensure_ascii=False, indent=2)

    return stats, stats_path


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--input_dir", type=str, default=None,
                       help="labeled Labeled directory path outputs/llama32_3b/01_emotion_elicited_generation_prompt_based/labeled")
    parser.add_argument("--both", action="store_true",
                       help="sev test_set Process both sev and test_set datasets")
    parser.add_argument("--model_name", type=str, default="llama32_3b",
                       help="Model folder name")
    parser.add_argument("--dataset", type=str, default=None,
                       help="Dataset name (sev, test_set)")
    args = parser.parse_args()

    # Determine labeled directory path
    if args.both or (not args.input_dir and not args.dataset):
        labeled_dir = Path("/content/drive/MyDrive/Various-Model/outputs") / args.model_name / "01_emotion_elicited_generation_prompt_based" / "labeled"

    elif args.input_dir:
        labeled_dir = Path(args.input_dir)
    else:
        parser.error(" --input_dir --both | Must specify --input_dir or --both")
        return

    if not labeled_dir.exists():
        print(f"[ERROR] Labeled directory not found: {labeled_dir}")
        return

    # Determine datasets to process
    if args.both:
        datasets = ["sev", "test_set"]
    elif args.dataset:
        datasets = [args.dataset]
    else:
        # Auto-discover all dataset folders
        datasets = [d.name for d in labeled_dir.iterdir() if d.is_dir()]

    if not datasets:
        print(f"[ERROR] No datasets found in {labeled_dir}")
        return

    print("=" * 70)
    print("Generating Accuracy Statistics")
    print("=" * 70)

    for dataset_name in datasets:
        result = generate_accuracy_stats(labeled_dir, dataset_name)

        if result:
            stats, stats_path = result

            print(f"\n📊 {dataset_name.upper()} :")
            print(f"   File: {stats_path}")
            print(f"   Total: {stats['overall']['total_samples']}")
            print(f"   Accepted: {stats['overall']['accepted']}")
            print(f"   Rejected: {stats['overall']['rejected']}")
            print(f"   Overall Accuracy: {stats['overall']['accuracy']}%")

            print(f"\n   By Emotion:")
            for emotion in sorted(stats['by_emotion'].keys()):
                e_stats = stats['by_emotion'][emotion]
                print(f"      {emotion:12s}: {e_stats['accepted']:4d}/{e_stats['total']:4d} = {e_stats['accuracy']:6.2f}%")

            if stats['by_valence']:
                print(f"\n   By Valence:")
                for valence in sorted(stats['by_valence'].keys()):
                    v_stats = stats['by_valence'][valence]
                    print(f"      {valence:12s}: {v_stats['accepted']:4d}/{v_stats['total']:4d} = {v_stats['accuracy']:6.2f}%")

    print("\n" + "=" * 70)
    print("✅ Statistics generation completed!")
    print("=" * 70)


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# Generating Accuracy Statistics
# ======================================================================
# Reading /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled/sev/accepted.jsonl...
# Reading /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled/sev/rejected.jsonl...
#
# 📊 SEV :
#    File: /content/drive/MyDrive/Various-Model/outputs/claude_sonnet_4/01_emotion_elicited_generation_prompt_based/labeled/sev/accuracy_stats.json
#    Total: 2876
#    Accepted: 2731
#    Rejected: 145
#    Overall Accuracy: 94.96%
#
#    By Emotion:
#       anger       :  474/ 480 =  98.75%
#       disgust     :  478/ 479 =  99.79%
#       fear        :  475/ 480 =  98.96%
#       happiness   :  480/ 480 = 100.00%
#       sadness     :  475/ 480 =  98.96%
#       surprise    :  349/ 477 =  73.17%
#
#    By Valence:
#       negative    :  858/ 956 =  89.75%
#       neutral     :  927/ 960 =  96.56%
#       positive    :  946/ 960 =  98.54%
#
# ======================================================================
# ✅ Statistics generation completed!
# ======================================================================
