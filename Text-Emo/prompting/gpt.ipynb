# %%
import sys
sys.argv = [
    "program",
    "--input_path", "/content/drive/MyDrive/Various-Model/data/sev.jsonl",
]

# %%
import os

os.environ["OPENAI_API_KEY"] = ""

# %%
# scripts/01_emotion_elicited_generation_prompt_based/1_emotion_elicited_generation.py

"""
Emotion-Elicited Text Generation Script
Uses emotion-guided prompts to generate text with OpenAI GPT models

Input: data/sev.jsonl or data/test_set.jsonl
Output: outputs/openai_gpt/01_emotion_elicited_generation_prompt_based/generated/{dataset_name}_generated.jsonl
"""

import os
import json
import time
import argparse
from pathlib import Path
from typing import Dict, Any, List
import openai
from openai import OpenAI

client = OpenAI()

# Emotion types
EMOTIONS = ["anger", "sadness", "happiness", "fear", "surprise", "disgust"]
# Event types
VALENCES = ["positive", "neutral", "negative"]


def build_messages_for_emotion(emotion: str, scenario: str, event: str) -> List[Dict[str, str]]:
    """
    Build emotion-guided conversation messages for OpenAI Chat API
    """
    system_message = f"""
    Always reply in {emotion} tone.
    Keep the reply to at most two sentences.
    """.strip()

    user_message = f"{scenario}\n{event}"

    return [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message},
    ]


def iter_user_inputs(path: Path):
    """
    Iterate through input file
    """
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            if "scenario" in obj and "event" in obj:
                yield obj


def generate_with_openai(
    messages: List[Dict[str, str]],
    model: str = "gpt-5-nano",
    max_completion_tokens: int = 100,
) -> str:
    """
    Generate text using OpenAI Responses API (GPT-5 compatible)
    """
    try:
        # GPT-5 specific parameters (no temperature support)
        response = client.responses.create(
            model=model,
            input=messages,
            max_output_tokens=max_completion_tokens,

            # 🔑 GPT-5 SPECIFIC SETTINGS
            reasoning={"effort": "minimal"},  # Required for gpt-5-nano
            text={"format": {"type": "text"}},  # Force text output
        )

        # Extract text from response
        if hasattr(response, "output_text") and response.output_text:
            return response.output_text.strip()

        return ""

    except Exception as e:
        print(f"Error during OpenAI API call: {e}")
        return ""


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--input_path", type=str, default=None,
                       help="Input data path, e.g., data/sev.jsonl or data/test_set.jsonl")
    parser.add_argument("--both", action="store_true",
                       help="Process both sev and test_set datasets")
    parser.add_argument("--model", type=str, default="gpt-5-nano",
                       help="OpenAI model name (gpt-5-nano, gpt-4-turbo, gpt-3.5-turbo, etc.)")
    parser.add_argument("--max_new_tokens", type=int, default=100,
                       help="Maximum tokens to generate")
    parser.add_argument("--seed", type=int, default=1234,
                       help="Random seed (for metadata only)")
    parser.add_argument("--valences", type=str, default="positive,neutral,negative",
                       help="Valence list")
    parser.add_argument("--emotions", type=str, default="anger,sadness,happiness,fear,surprise,disgust",
                       help="Emotion list")
    parser.add_argument("--skip_if_exists", action="store_true", default=True,
                       help="Skip already processed items")
    parser.add_argument("--no_skip", action="store_true",
                       help="Reprocess all items")
    parser.add_argument("--api_key", type=str, default=None,
                       help="OpenAI API key (overrides the default)")
    parser.add_argument("--reasoning_effort", type=str, default="minimal",
                       choices=["minimal", "low", "medium", "high"],
                       help="Reasoning effort level for GPT-5 models")
    args = parser.parse_args()

    # Use provided API key or default
    if args.api_key:
        client.api_key = args.api_key

    # Determine input file list
    if args.both:
        input_paths = [Path("data/sev.jsonl"), Path("data/test_set.jsonl")]
    elif args.input_path:
        input_paths = [Path(args.input_path)]
    else:
        parser.error("Must specify --input_path or --both")
        return

    # Create model folder name for output organization
    model_name_clean = args.model.lower().replace('-', '_').replace('.', '_')
    model_folder = f"openai_{model_name_clean}"

    # Set emotions and valences from arguments
    emotions = [e.strip() for e in args.emotions.split(",") if e.strip()]
    valences = [v.strip() for v in args.valences.split(",") if v.strip()]

    # Process each input file
    for data_path in input_paths:
        if not data_path.exists():
            print(f"[WARNING] Input file not found: {data_path}, skipping...")
            continue

        dataset_name = data_path.stem  # sev or test_set

        # Build output path
        out_dir = Path("/content/drive/MyDrive/Various-Model/outputs") / model_folder / "01_emotion_elicited_generation_prompt_based" / "generated"
        out_dir.mkdir(parents=True, exist_ok=True)

        jsonl_path = out_dir / f"{dataset_name}_generated.jsonl"

        # Load existing keys (for resuming from checkpoint)
        existing_keys = set()
        if args.skip_if_exists and not args.no_skip and jsonl_path.exists():
            with open(jsonl_path, "r", encoding="utf-8") as f:
                for line in f:
                    try:
                        obj = json.loads(line.strip())
                        if "key" in obj:
                            existing_keys.add(obj["key"])
                    except:
                        continue

        print(f"{'='*70}")
        print(f"Processing dataset: {dataset_name}")
        print(f"Input: {data_path}")
        print(f"Output: {jsonl_path}")
        print(f"Model: {args.model}")
        print(f"Reasoning Effort: {args.reasoning_effort}")
        print(f"{'='*70}\n")

        total = 0
        skipped = 0
        start = time.time()

        with open(jsonl_path, "a", encoding="utf-8") as fout:
            for item in iter_user_inputs(data_path):
                theme = item.get("theme", "")
                scenario = item["scenario"]
                events = item["event"]  # dict: positive/neutral/negative events
                sid = item.get("skeleton_id", "unknown")

                for val in valences:
                    if val not in events:
                        continue
                    event = events[val]

                    for emo in emotions:
                        key = f"{sid}__{val}__{emo}".replace("/", "_")

                        # Checkpoint resuming check
                        if key in existing_keys:
                            skipped += 1
                            if skipped % 50 == 0:
                                print(f"[SKIP] {skipped} items skipped so far... (last: {key})")
                            continue

                        # Build messages and generate
                        msgs = build_messages_for_emotion(emo, scenario, event)
                        gen_text = generate_with_openai(
                            messages=msgs,
                            model=args.model,
                            max_completion_tokens=args.max_new_tokens,
                        )

                        # Save to jsonl
                        row = {
                            "key": key,
                            "skeleton_id": sid,
                            "theme": theme,
                            "valence": val,
                            "emotion": emo,
                            "scenario": scenario,
                            "event": event,
                            "gen_text": gen_text,
                            "meta": {
                                "model_id": args.model,
                                "provider": "openai",
                                "max_new_tokens": args.max_new_tokens,
                                "reasoning_effort": args.reasoning_effort,
                                "seed": args.seed,
                                "time": int(time.time()),
                            }
                        }
                        fout.write(json.dumps(row, ensure_ascii=False) + "\n")
                        fout.flush()  # Flush to disk immediately

                        total += 1
                        if total % 20 == 0:
                            el = time.time() - start
                            rate = total / el if el > 0 else 0
                            print(f"[progress] generated={total} | last={key} | {el:.1f}s elapsed | {rate:.2f} items/s")

        elapsed = time.time() - start
        print(f"\n[OK] {dataset_name} completed. Generated {total} items, skipped {skipped} items.")
        print(f"     Time: {elapsed:.1f}s | Rate: {total/elapsed:.2f} items/s")
        print(f"     Output: {jsonl_path}\n")


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# Processing dataset: sev
# Input: /content/drive/MyDrive/Various-Model/data/sev.jsonl
# Output: /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl
# Model: gpt-5-nano
# Reasoning Effort: minimal
# ======================================================================
#
# [progress] generated=20 | last=work_01__positive__sadness | 19.6s elapsed | 1.02 items/s
# [progress] generated=40 | last=work_02__positive__fear | 38.6s elapsed | 1.04 items/s
# [progress] generated=60 | last=work_03__positive__disgust | 58.8s elapsed | 1.02 items/s
# [progress] generated=80 | last=work_04__neutral__sadness | 79.4s elapsed | 1.01 items/s
# [progress] generated=100 | last=work_05__neutral__fear | 98.3s elapsed | 1.02 items/s
# [progress] generated=120 | last=work_06__neutral__disgust | 117.5s elapsed | 1.02 items/s
# [progress] generated=140 | last=work_07__negative__sadness | 137.8s elapsed | 1.02 items/s
# [progress] generated=160 | last=work_08__negative__fear | 157.3s elapsed | 1.02 items/s
# [progress] generated=180 | last=work_09__negative__disgust | 178.0s elapsed | 1.01 items/s
# [progress] generated=200 | last=work_11__positive__sadness | 197.2s elapsed | 1.01 items/s
# [progress] generated=220 | last=work_12__positive__fear | 216.4s elapsed | 1.02 items/s
# [progress] generated=240 | last=work_13__positive__disgust | 236.3s elapsed | 1.02 items/s
# [progress] generated=260 | last=work_14__neutral__sadness | 254.8s elapsed | 1.02 items/s
# [progress] generated=280 | last=work_15__neutral__fear | 276.1s elapsed | 1.01 items/s
# [progress] generated=300 | last=work_16__neutral__disgust | 296.1s elapsed | 1.01 items/s
# [progress] generated=320 | last=work_17__negative__sadness | 316.3s elapsed | 1.01 items/s
# [progress] generated=340 | last=work_18__negative__fear | 336.6s elapsed | 1.01 items/s
# [progress] generated=360 | last=work_19__negative__disgust | 355.5s elapsed | 1.01 items/s
# [progress] generated=380 | last=school_01__positive__sadness | 374.5s elapsed | 1.01 items/s
# [progress] generated=400 | last=school_02__positive__fear | 396.6s elapsed | 1.01 items/s
# [progress] generated=420 | last=school_03__positive__disgust | 419.2s elapsed | 1.00 items/s
# [progress] generated=440 | last=school_04__neutral__sadness | 444.1s elapsed | 0.99 items/s
# [progress] generated=460 | last=school_05__neutral__fear | 462.6s elapsed | 0.99 items/s
# [progress] generated=480 | last=school_06__neutral__disgust | 481.9s elapsed | 1.00 items/s
# [progress] generated=500 | last=school_07__negative__sadness | 501.2s elapsed | 1.00 items/s
# [progress] generated=520 | last=school_08__negative__fear | 521.8s elapsed | 1.00 items/s
# [progress] generated=540 | last=school_09__negative__disgust | 544.9s elapsed | 0.99 items/s
# [progress] generated=560 | last=school_11__positive__sadness | 564.5s elapsed | 0.99 items/s
# [progress] generated=580 | last=school_12__positive__fear | 582.2s elapsed | 1.00 items/s
# [progress] generated=600 | last=school_13__positive__disgust | 601.1s elapsed | 1.00 items/s
# [progress] generated=620 | last=school_14__neutral__sadness | 621.5s elapsed | 1.00 items/s
# [progress] generated=640 | last=school_15__neutral__fear | 641.6s elapsed | 1.00 items/s
# [progress] generated=660 | last=school_16__neutral__disgust | 660.7s elapsed | 1.00 items/s
# [progress] generated=680 | last=school_17__negative__sadness | 679.0s elapsed | 1.00 items/s
# [progress] generated=700 | last=school_18__negative__fear | 697.3s elapsed | 1.00 items/s
# [progress] generated=720 | last=school_19__negative__disgust | 715.6s elapsed | 1.01 items/s
# [progress] generated=740 | last=relation_01__positive__sadness | 733.9s elapsed | 1.01 items/s
# [progress] generated=760 | last=relation_02__positive__fear | 753.5s elapsed | 1.01 items/s
# [progress] generated=780 | last=relation_03__positive__disgust | 778.5s elapsed | 1.00 items/s
# [progress] generated=800 | last=relation_04__neutral__sadness | 798.2s elapsed | 1.00 items/s
# [progress] generated=820 | last=relation_05__neutral__fear | 815.9s elapsed | 1.01 items/s
# [progress] generated=840 | last=relation_06__neutral__disgust | 845.2s elapsed | 0.99 items/s
# [progress] generated=860 | last=relation_07__negative__sadness | 863.3s elapsed | 1.00 items/s
# [progress] generated=880 | last=relation_08__negative__fear | 884.2s elapsed | 1.00 items/s
# [progress] generated=900 | last=relation_09__negative__disgust | 906.0s elapsed | 0.99 items/s
# [progress] generated=920 | last=relation_11__positive__sadness | 923.9s elapsed | 1.00 items/s
# [progress] generated=940 | last=relation_12__positive__fear | 944.7s elapsed | 1.00 items/s
# [progress] generated=960 | last=relation_13__positive__disgust | 962.6s elapsed | 1.00 items/s
# [progress] generated=980 | last=relation_14__neutral__sadness | 983.0s elapsed | 1.00 items/s
# [progress] generated=1000 | last=relation_15__neutral__fear | 1007.0s elapsed | 0.99 items/s
# [progress] generated=1020 | last=relation_16__neutral__disgust | 1026.6s elapsed | 0.99 items/s
# [progress] generated=1040 | last=relation_17__negative__sadness | 1047.2s elapsed | 0.99 items/s
# [progress] generated=1060 | last=relation_18__negative__fear | 1066.6s elapsed | 0.99 items/s
# [progress] generated=1080 | last=relation_19__negative__disgust | 1086.5s elapsed | 0.99 items/s
# [progress] generated=1100 | last=shopping_01__positive__sadness | 1105.3s elapsed | 1.00 items/s
# [progress] generated=1120 | last=shopping_02__positive__fear | 1126.9s elapsed | 0.99 items/s
# [progress] generated=1140 | last=shopping_03__positive__disgust | 1147.9s elapsed | 0.99 items/s
# [progress] generated=1160 | last=shopping_04__neutral__sadness | 1166.1s elapsed | 0.99 items/s
# [progress] generated=1180 | last=shopping_05__neutral__fear | 1186.4s elapsed | 0.99 items/s
# [progress] generated=1200 | last=shopping_06__neutral__disgust | 1209.9s elapsed | 0.99 items/s
# [progress] generated=1220 | last=shopping_07__negative__sadness | 1232.0s elapsed | 0.99 items/s
# [progress] generated=1240 | last=shopping_08__negative__fear | 1253.9s elapsed | 0.99 items/s
# [progress] generated=1260 | last=shopping_09__negative__disgust | 1275.9s elapsed | 0.99 items/s
# [progress] generated=1280 | last=shopping_11__positive__sadness | 1298.2s elapsed | 0.99 items/s
# [progress] generated=1300 | last=shopping_12__positive__fear | 1318.5s elapsed | 0.99 items/s
# [progress] generated=1320 | last=shopping_13__positive__disgust | 1342.3s elapsed | 0.98 items/s
# [progress] generated=1340 | last=shopping_14__neutral__sadness | 1366.7s elapsed | 0.98 items/s
# [progress] generated=1360 | last=shopping_15__neutral__fear | 1389.5s elapsed | 0.98 items/s
# [progress] generated=1380 | last=shopping_16__neutral__disgust | 1409.5s elapsed | 0.98 items/s
# [progress] generated=1400 | last=shopping_17__negative__sadness | 1432.1s elapsed | 0.98 items/s
# [progress] generated=1420 | last=shopping_18__negative__fear | 1453.1s elapsed | 0.98 items/s
# [progress] generated=1440 | last=shopping_19__negative__disgust | 1474.6s elapsed | 0.98 items/s
# [progress] generated=1460 | last=administration_01__positive__sadness | 1495.6s elapsed | 0.98 items/s
# [progress] generated=1480 | last=administration_02__positive__fear | 1515.6s elapsed | 0.98 items/s
# [progress] generated=1500 | last=administration_03__positive__disgust | 1535.2s elapsed | 0.98 items/s
# [progress] generated=1520 | last=administration_04__neutral__sadness | 1557.8s elapsed | 0.98 items/s
# [progress] generated=1540 | last=administration_05__neutral__fear | 1578.0s elapsed | 0.98 items/s
# [progress] generated=1560 | last=administration_06__neutral__disgust | 1598.4s elapsed | 0.98 items/s
# [progress] generated=1580 | last=administration_07__negative__sadness | 1620.6s elapsed | 0.97 items/s
# [progress] generated=1600 | last=administration_08__negative__fear | 1642.5s elapsed | 0.97 items/s
# [progress] generated=1620 | last=administration_09__negative__disgust | 1662.9s elapsed | 0.97 items/s
# [progress] generated=1640 | last=administration_11__positive__sadness | 1683.5s elapsed | 0.97 items/s
# [progress] generated=1660 | last=administration_12__positive__fear | 1703.4s elapsed | 0.97 items/s
# [progress] generated=1680 | last=administration_13__positive__disgust | 1723.8s elapsed | 0.97 items/s
# [progress] generated=1700 | last=administration_14__neutral__sadness | 1744.0s elapsed | 0.97 items/s
# [progress] generated=1720 | last=administration_15__neutral__fear | 1763.2s elapsed | 0.98 items/s
# [progress] generated=1740 | last=administration_16__neutral__disgust | 1782.7s elapsed | 0.98 items/s
# [progress] generated=1760 | last=administration_17__negative__sadness | 1802.8s elapsed | 0.98 items/s
# [progress] generated=1780 | last=administration_18__negative__fear | 1829.8s elapsed | 0.97 items/s
# [progress] generated=1800 | last=administration_19__negative__disgust | 1852.5s elapsed | 0.97 items/s
# [progress] generated=1820 | last=health_01__positive__sadness | 1871.5s elapsed | 0.97 items/s
# [progress] generated=1840 | last=health_02__positive__fear | 1893.0s elapsed | 0.97 items/s
# [progress] generated=1860 | last=health_03__positive__disgust | 1914.9s elapsed | 0.97 items/s
# [progress] generated=1880 | last=health_04__neutral__sadness | 1934.1s elapsed | 0.97 items/s
# [progress] generated=1900 | last=health_05__neutral__fear | 1956.7s elapsed | 0.97 items/s
# [progress] generated=1920 | last=health_06__neutral__disgust | 1974.9s elapsed | 0.97 items/s
# [progress] generated=1940 | last=health_07__negative__sadness | 1995.3s elapsed | 0.97 items/s
# [progress] generated=1960 | last=health_08__negative__fear | 2015.7s elapsed | 0.97 items/s
# [progress] generated=1980 | last=health_09__negative__disgust | 2035.5s elapsed | 0.97 items/s
# [progress] generated=2000 | last=health_11__positive__sadness | 2056.2s elapsed | 0.97 items/s
# [progress] generated=2020 | last=health_12__positive__fear | 2077.4s elapsed | 0.97 items/s
# [progress] generated=2040 | last=health_13__positive__disgust | 2098.9s elapsed | 0.97 items/s
# [progress] generated=2060 | last=health_14__neutral__sadness | 2119.9s elapsed | 0.97 items/s
# [progress] generated=2080 | last=health_15__neutral__fear | 2140.2s elapsed | 0.97 items/s
# [progress] generated=2100 | last=health_16__neutral__disgust | 2160.1s elapsed | 0.97 items/s
# [progress] generated=2120 | last=health_17__negative__sadness | 2180.4s elapsed | 0.97 items/s
# [progress] generated=2140 | last=health_18__negative__fear | 2202.0s elapsed | 0.97 items/s
# [progress] generated=2160 | last=health_19__negative__disgust | 2225.2s elapsed | 0.97 items/s
# [progress] generated=2180 | last=living_01__positive__sadness | 2245.8s elapsed | 0.97 items/s
# [progress] generated=2200 | last=living_02__positive__fear | 2267.9s elapsed | 0.97 items/s
# [progress] generated=2220 | last=living_03__positive__disgust | 2288.3s elapsed | 0.97 items/s
# [progress] generated=2240 | last=living_04__neutral__sadness | 2310.2s elapsed | 0.97 items/s
# [progress] generated=2260 | last=living_05__neutral__fear | 2330.1s elapsed | 0.97 items/s
# [progress] generated=2280 | last=living_06__neutral__disgust | 2353.9s elapsed | 0.97 items/s
# [progress] generated=2300 | last=living_07__negative__sadness | 2375.5s elapsed | 0.97 items/s
# [progress] generated=2320 | last=living_08__negative__fear | 2396.2s elapsed | 0.97 items/s
# [progress] generated=2340 | last=living_09__negative__disgust | 2416.3s elapsed | 0.97 items/s
# [progress] generated=2360 | last=living_11__positive__sadness | 2437.7s elapsed | 0.97 items/s
# [progress] generated=2380 | last=living_12__positive__fear | 2459.9s elapsed | 0.97 items/s
# [progress] generated=2400 | last=living_13__positive__disgust | 2479.3s elapsed | 0.97 items/s
# [progress] generated=2420 | last=living_14__neutral__sadness | 2499.2s elapsed | 0.97 items/s
# [progress] generated=2440 | last=living_15__neutral__fear | 2518.9s elapsed | 0.97 items/s
# [progress] generated=2460 | last=living_16__neutral__disgust | 2542.7s elapsed | 0.97 items/s
# [progress] generated=2480 | last=living_17__negative__sadness | 2565.1s elapsed | 0.97 items/s
# [progress] generated=2500 | last=living_18__negative__fear | 2587.9s elapsed | 0.97 items/s
# [progress] generated=2520 | last=living_19__negative__disgust | 2607.4s elapsed | 0.97 items/s
# [progress] generated=2540 | last=travel_01__positive__sadness | 2626.7s elapsed | 0.97 items/s
# [progress] generated=2560 | last=travel_02__positive__fear | 2647.9s elapsed | 0.97 items/s
# [progress] generated=2580 | last=travel_03__positive__disgust | 2667.1s elapsed | 0.97 items/s
# [progress] generated=2600 | last=travel_04__neutral__sadness | 2687.8s elapsed | 0.97 items/s
# [progress] generated=2620 | last=travel_05__neutral__fear | 2706.7s elapsed | 0.97 items/s
# [progress] generated=2640 | last=travel_06__neutral__disgust | 2727.6s elapsed | 0.97 items/s
# [progress] generated=2660 | last=travel_07__negative__sadness | 2748.8s elapsed | 0.97 items/s
# [progress] generated=2680 | last=travel_08__negative__fear | 2769.7s elapsed | 0.97 items/s
# [progress] generated=2700 | last=travel_09__negative__disgust | 2789.4s elapsed | 0.97 items/s
# [progress] generated=2720 | last=travel_11__positive__sadness | 2810.0s elapsed | 0.97 items/s
# [progress] generated=2740 | last=travel_12__positive__fear | 2835.4s elapsed | 0.97 items/s
# [progress] generated=2760 | last=travel_13__positive__disgust | 2856.6s elapsed | 0.97 items/s
# [progress] generated=2780 | last=travel_14__neutral__sadness | 2878.0s elapsed | 0.97 items/s
# [progress] generated=2800 | last=travel_15__neutral__fear | 2898.7s elapsed | 0.97 items/s
# [progress] generated=2820 | last=travel_16__neutral__disgust | 2921.4s elapsed | 0.97 items/s
# [progress] generated=2840 | last=travel_17__negative__sadness | 2941.3s elapsed | 0.97 items/s
# [progress] generated=2860 | last=travel_18__negative__fear | 2962.1s elapsed | 0.97 items/s
# [progress] generated=2880 | last=travel_19__negative__disgust | 2982.4s elapsed | 0.97 items/s
#
# [OK] sev completed. Generated 2880 items, skipped 0 items.
#      Time: 2982.4s | Rate: 0.97 items/s
#      Output: /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl

# %%
import sys
sys.argv = [
    "program",
    "--input_path", "/content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl",
]

# %%
 # scripts/01_emotion_elicited_generation_prompt_based/2_label_generated_with_gpt.py
# -*- coding: utf-8 -*-
"""
Emotion Text Labeling Script

Batch labeling script: Reads texts generated by script 1, uses GPT-4o-mini to label, saves by accepted/rejected

- 输入 Input: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/generated/{dataset_name}_generated.jsonl
- 输出 Output: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/labeled/{dataset_name}/{accepted|rejected}.jsonl
"""

import os, json, time, argparse
from pathlib import Path
from typing import Dict, Any

from openai import OpenAI

# ====== OpenAI (GPT-4o-mini 打标) ======
client = OpenAI()

EMOTIONS = ["anger","sadness","happiness","fear","surprise","disgust"]

SYSTEM_LBL = f'''
You are a careful rater.
Given a target emotion and a text,
decide if the text's STYLE matches the target emotion among:
{EMOTIONS}
Focus on tone/attitude, not content valence.
'''.strip()

USER_TMPL_LBL = '''
Target emotion: {emotion}
Text:
{text}
Decide if the text's STYLE matches the target emotion.
Return a compact JSON with keys exactly:
{{
"match": <0 or 1>,
"reason": <short string>
}}
'''.strip()


def extract_json_from_response(response: str) -> str:
    """
    从GPT响应中提取JSON内容，处理markdown格式
    Extract JSON content from GPT response, handling markdown format
    """
    response = response.strip()

    # 如果包含markdown代码块，提取其中的JSON
    # If contains markdown code block, extract JSON from it
    if "```json" in response:
        start = response.find("```json") + 7
        end = response.find("```", start)
        if end != -1:
            return response[start:end].strip()
    elif "```" in response:
        # 处理没有json标识的代码块
        # Handle code blocks without json identifier
        start = response.find("```") + 3
        end = response.find("```", start)
        if end != -1:
            return response[start:end].strip()

    # 如果没有代码块，直接返回原内容
    # If no code block, return original content
    return response


def ask_llm_label(client, model: str, emotion: str, text: str,
                  max_retries=4, backoff=1.8) -> Dict[str, Any]:
    """
    调用 GPT-4o-mini 打标；无 KEY 或错误则返回未标注
    Call GPT-4o-mini for labeling; return unlabeled if no KEY or error
    """
    for i in range(max_retries):
        try:
            user_content = USER_TMPL_LBL.format(emotion=emotion, text=text)
            try:
                resp = client.chat.completions.create(
                    model=model,
                    messages=[
                        {"role": "system", "content": SYSTEM_LBL},
                        {"role": "user",   "content": user_content}
                    ],
                )
            except Exception as api_error:
                if i == max_retries - 1:
                    return {"match": 0, "reason": f"api-error:{type(api_error).__name__}"}
                time.sleep(backoff ** i)
                continue

            # 安全地获取响应内容
            # Safely get response content
            try:
                choice = resp.choices[0]
                message = choice.message
                content = message.content
                out = (content or "").strip()
            except (KeyError, IndexError, AttributeError) as ke:
                return {"match": 0, "reason": f"response-structure-error: {type(ke).__name__}"}

            js = extract_json_from_response(out)
            try:
                j = json.loads(js)
                if "match" not in j: j = {"match": 0, "reason": "invalid-json"}
                if "reason" not in j: j["reason"] = "no-reason-provided"
                return j
            except json.JSONDecodeError as je:
                return {"match": 0, "reason": f"json-decode-error: {str(je)}"}
        except Exception as e:
            if i == max_retries - 1:
                return {"match": 0, "reason": f"error:{type(e).__name__}"}
            time.sleep(backoff ** i)

    return {"match": 0, "reason": "max-retries-exceeded"}


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--input_path", type=str, default=None,
                       help="输入数据路径 Input data path，如 outputs/llama32_3b/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl")
    parser.add_argument("--both", action="store_true",
                       help="处理sev和test_set两个数据集 Process both sev and test_set datasets")
    parser.add_argument("--model_name", type=str, default="llama32_3b",
                       help="模型文件夹名 Model folder name")
    parser.add_argument("--lbl_model", type=str, default="gpt-4o-mini",
                       help="打标模型 Label model")
    parser.add_argument("--skip_if_exists", action="store_true", default=True,
                       help="跳过已打标的项目 Skip already labeled items")
    parser.add_argument("--no_skip", action="store_true",
                       help="重新打标所有项目 Relabel all items")
    args = parser.parse_args()

    # 确定输入文件列表
    # Determine input file list
    if args.both:
        base_path = Path("/content/drive/MyDrive/Various-Model/outputs") / args.model_name / "01_emotion_elicited_generation_prompt_based" / "generated"
        input_paths = [
            base_path / "sev_generated.jsonl",
            base_path / "test_set_generated.jsonl"
        ]
    elif args.input_path:
        input_paths = [Path(args.input_path)]
    else:
        parser.error("必须指定 --input_path 或 --both | Must specify --input_path or --both")
        return

    # 处理每个输入文件
    # Process each input file
    for input_path in input_paths:
        if not input_path.exists():
            print(f"[WARNING] Input file not found: {input_path}, skipping...")
            continue

        # 从输入路径提取 model_name 和 dataset_name
        # Extract model_name and dataset_name from input path
        parts = input_path.parts
        if "outputs" in parts and "01_emotion_elicited_generation_prompt_based" in parts and "generated" in parts:
            outputs_idx = parts.index("outputs")
            model_name = parts[outputs_idx + 1]
            # 从文件名提取dataset_name (例如: sev_generated.jsonl -> sev)
            filename = input_path.stem  # 去掉.jsonl
            if filename.endswith("_generated"):
                dataset_name = filename[:-10]  # 去掉_generated后缀
            else:
                dataset_name = filename
        else:
            print(f"[ERROR] Input path format incorrect: {input_path}")
            print(f"        Expected: outputs/{{model_name}}/01_emotion_elicited_generation_prompt_based/generated/{{dataset_name}}_generated.jsonl")
            continue

        # 构建输出路径
        # Build output path
        out_dir = Path("/content/drive/MyDrive/Various-Model/outputs") / model_name / "01_emotion_elicited_generation_prompt_based" / "labeled" / dataset_name
        out_dir.mkdir(parents=True, exist_ok=True)

        acc_path = out_dir / "accepted.jsonl"
        rej_path = out_dir / "rejected.jsonl"

        # 加载已打标的 keys（用于断点续跑）
        # Load existing keys (for resuming from checkpoint)
        existing_keys = set()
        if args.skip_if_exists and not args.no_skip:
            for path in [acc_path, rej_path]:
                if path.exists():
                    with open(path, "r", encoding="utf-8") as f:
                        for line in f:
                            try:
                                obj = json.loads(line.strip())
                                if "key" in obj:
                                    existing_keys.add(obj["key"])
                            except:
                                continue

        print(f"{'='*70}")
        print(f"Processing dataset: {dataset_name}")
        print(f"Input: {input_path}")
        print(f"Output: {out_dir}")
        print(f"{'='*70}\n")

        total = 0
        skipped = 0
        accepted = 0
        rejected = 0
        start = time.time()

        # 统计字典：按情绪和极性分类
        # Statistics dictionaries: by emotion and valence
        stats_by_emotion = {}  # {emotion: {"total": N, "accepted": M}}
        stats_by_valence = {}  # {valence: {"total": N, "accepted": M}}

        with open(input_path, "r", encoding="utf-8") as fin:
            for line in fin:
                line = line.strip()
                if not line: continue

                try:
                    item = json.loads(line)
                except json.JSONDecodeError:
                    print(f"[WARN] Failed to parse line: {line[:100]}...")
                    continue

                key = item.get("key", "unknown")

                # 断点续跑检查
                # Checkpoint resuming check
                if key in existing_keys:
                    skipped += 1
                    if skipped % 50 == 0:
                        print(f"[SKIP] {skipped} items skipped so far... (last: {key})")
                    continue

                emotion = item.get("emotion", "")
                valence = item.get("valence", "")
                gen_text = item.get("gen_text", "")

                # GPT 打标
                # GPT labeling
                label = {"match": 0, "reason": "empty-text"}
                if isinstance(gen_text, str) and gen_text:
                    label = ask_llm_label(client, args.lbl_model, emotion, gen_text)

                # 添加打标结果和打标时间
                # Add labeling result and timestamp
                item["judge"] = label
                item["label_time"] = int(time.time())

                # 根据打标结果保存
                # Save based on labeling result
                match_score = int(label.get("match", 0))
                if match_score == 1:
                    output_path = acc_path
                    accepted += 1
                    category = "accepted"
                else:
                    output_path = rej_path
                    rejected += 1
                    category = "rejected"

                with open(output_path, "a", encoding="utf-8") as fout:
                    fout.write(json.dumps(item, ensure_ascii=False) + "\n")

                # 更新统计
                # Update statistics
                if emotion:
                    if emotion not in stats_by_emotion:
                        stats_by_emotion[emotion] = {"total": 0, "accepted": 0}
                    stats_by_emotion[emotion]["total"] += 1
                    stats_by_emotion[emotion]["accepted"] += match_score

                if valence:
                    if valence not in stats_by_valence:
                        stats_by_valence[valence] = {"total": 0, "accepted": 0}
                    stats_by_valence[valence]["total"] += 1
                    stats_by_valence[valence]["accepted"] += match_score

                total += 1
                if total % 10 == 0:
                    el = time.time() - start
                    rate = total / el if el > 0 else 0
                    print(f"[progress] labeled={total} (acc={accepted}, rej={rejected}) | last={key} [{category}] | {el:.1f}s | {rate:.2f} items/s")

        elapsed = time.time() - start
        print(f"\n[OK] {dataset_name} completed. Labeled {total} items, skipped {skipped} items.")
        print(f"     Accepted: {accepted} | Rejected: {rejected}")
        print(f"     Time: {elapsed:.1f}s | Rate: {total/elapsed:.2f} items/s")
        print(f"     Output:")
        print(f"       - {acc_path}")
        print(f"       - {rej_path}")

        # ===== 输出统计信息 =====
        # ===== Output statistics =====
        print("\n" + "="*60)
        print(f"📊 ACCURACY STATISTICS - {dataset_name.upper()}")
        print("="*60)

        # 总体正确率
        # Overall accuracy
        overall_acc = (accepted / total * 100) if total > 0 else 0
        print(f"\n🎯 Overall Accuracy: {accepted}/{total} = {overall_acc:.2f}%")

        # 按情绪统计
        # Statistics by emotion
        print(f"\n📈 Accuracy by Emotion:")
        print("-" * 60)
        print(f"{'Emotion':<15} {'Accepted':<12} {'Total':<10} {'Accuracy':<12}")
        print("-" * 60)

        emotions_sorted = sorted(stats_by_emotion.items())
        for emotion, stats in emotions_sorted:
            acc_count = stats["accepted"]
            tot_count = stats["total"]
            acc_rate = (acc_count / tot_count * 100) if tot_count > 0 else 0
            print(f"{emotion:<15} {acc_count:<12} {tot_count:<10} {acc_rate:>6.2f}%")

        # 按极性统计
        # Statistics by valence
        print(f"\n📉 Accuracy by Valence:")
        print("-" * 60)
        print(f"{'Valence':<15} {'Accepted':<12} {'Total':<10} {'Accuracy':<12}")
        print("-" * 60)

        valences_sorted = sorted(stats_by_valence.items())
        for valence, stats in valences_sorted:
            acc_count = stats["accepted"]
            tot_count = stats["total"]
            acc_rate = (acc_count / tot_count * 100) if tot_count > 0 else 0
            print(f"{valence:<15} {acc_count:<12} {tot_count:<10} {acc_rate:>6.2f}%")

        print("="*60 + "\n")


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# Processing dataset: sev
# Input: /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/generated/sev_generated.jsonl
# Output: /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled/sev
# ======================================================================
#
# [progress] labeled=10 (acc=10, rej=0) | last=work_02__positive__anger [accepted] | 14.2s | 0.71 items/s
# [progress] labeled=20 (acc=20, rej=0) | last=work_02__neutral__surprise [accepted] | 23.1s | 0.86 items/s
# [progress] labeled=30 (acc=28, rej=2) | last=work_03__positive__happiness [accepted] | 33.7s | 0.89 items/s
# [progress] labeled=40 (acc=37, rej=3) | last=work_03__negative__anger [accepted] | 45.3s | 0.88 items/s
# [progress] labeled=50 (acc=47, rej=3) | last=work_04__positive__surprise [accepted] | 56.0s | 0.89 items/s
# [progress] labeled=60 (acc=54, rej=6) | last=work_04__negative__happiness [rejected] | 67.0s | 0.90 items/s
# [progress] labeled=70 (acc=63, rej=7) | last=work_05__neutral__anger [accepted] | 76.7s | 0.91 items/s
# [progress] labeled=80 (acc=71, rej=9) | last=work_05__negative__surprise [rejected] | 85.8s | 0.93 items/s
# [progress] labeled=90 (acc=81, rej=9) | last=work_06__neutral__happiness [accepted] | 95.6s | 0.94 items/s
# [progress] labeled=100 (acc=89, rej=11) | last=work_07__positive__anger [accepted] | 107.9s | 0.93 items/s
# [progress] labeled=110 (acc=99, rej=11) | last=work_07__neutral__surprise [accepted] | 118.9s | 0.93 items/s
# [progress] labeled=120 (acc=107, rej=13) | last=work_08__positive__happiness [accepted] | 128.9s | 0.93 items/s
# [progress] labeled=130 (acc=116, rej=14) | last=work_08__negative__anger [accepted] | 139.2s | 0.93 items/s
# [progress] labeled=140 (acc=124, rej=16) | last=work_09__positive__surprise [rejected] | 149.3s | 0.94 items/s
# [progress] labeled=150 (acc=132, rej=18) | last=work_09__negative__happiness [accepted] | 159.7s | 0.94 items/s
# [progress] labeled=160 (acc=140, rej=20) | last=work_10__neutral__anger [accepted] | 169.4s | 0.94 items/s
# [progress] labeled=170 (acc=149, rej=21) | last=work_10__negative__surprise [accepted] | 179.2s | 0.95 items/s
# [progress] labeled=180 (acc=159, rej=21) | last=work_11__neutral__happiness [accepted] | 190.9s | 0.94 items/s
# [progress] labeled=190 (acc=167, rej=23) | last=work_12__positive__anger [accepted] | 202.4s | 0.94 items/s
# [progress] labeled=200 (acc=176, rej=24) | last=work_12__neutral__surprise [rejected] | 213.6s | 0.94 items/s
# [progress] labeled=210 (acc=184, rej=26) | last=work_13__positive__happiness [accepted] | 222.6s | 0.94 items/s
# [progress] labeled=220 (acc=193, rej=27) | last=work_13__negative__anger [accepted] | 236.7s | 0.93 items/s
# [progress] labeled=230 (acc=202, rej=28) | last=work_14__positive__surprise [accepted] | 247.8s | 0.93 items/s
# [progress] labeled=240 (acc=211, rej=29) | last=work_14__negative__happiness [accepted] | 257.4s | 0.93 items/s
# [progress] labeled=250 (acc=219, rej=31) | last=work_15__neutral__anger [rejected] | 267.1s | 0.94 items/s
# [progress] labeled=260 (acc=229, rej=31) | last=work_15__negative__surprise [accepted] | 277.7s | 0.94 items/s
# [progress] labeled=270 (acc=239, rej=31) | last=work_16__neutral__happiness [accepted] | 289.3s | 0.93 items/s
# [progress] labeled=280 (acc=245, rej=35) | last=work_17__positive__anger [accepted] | 298.8s | 0.94 items/s
# [progress] labeled=290 (acc=254, rej=36) | last=work_17__neutral__surprise [accepted] | 309.0s | 0.94 items/s
# [progress] labeled=300 (acc=261, rej=39) | last=work_18__positive__happiness [accepted] | 319.9s | 0.94 items/s
# [progress] labeled=310 (acc=271, rej=39) | last=work_18__negative__anger [accepted] | 330.0s | 0.94 items/s
# [progress] labeled=320 (acc=280, rej=40) | last=work_19__positive__surprise [accepted] | 339.2s | 0.94 items/s
# [progress] labeled=330 (acc=289, rej=41) | last=work_19__negative__happiness [accepted] | 348.4s | 0.95 items/s
# [progress] labeled=340 (acc=298, rej=42) | last=school_00__neutral__anger [accepted] | 357.8s | 0.95 items/s
# [progress] labeled=350 (acc=308, rej=42) | last=school_00__negative__surprise [accepted] | 366.6s | 0.95 items/s
# [progress] labeled=360 (acc=318, rej=42) | last=school_01__neutral__happiness [accepted] | 376.8s | 0.96 items/s
# [progress] labeled=370 (acc=327, rej=43) | last=school_02__positive__anger [accepted] | 386.8s | 0.96 items/s
# [progress] labeled=380 (acc=336, rej=44) | last=school_02__neutral__surprise [accepted] | 395.7s | 0.96 items/s
# [progress] labeled=390 (acc=344, rej=46) | last=school_03__positive__happiness [accepted] | 405.3s | 0.96 items/s
# [progress] labeled=400 (acc=353, rej=47) | last=school_03__negative__anger [accepted] | 415.2s | 0.96 items/s
# [progress] labeled=410 (acc=360, rej=50) | last=school_04__positive__surprise [accepted] | 426.0s | 0.96 items/s
# [progress] labeled=420 (acc=368, rej=52) | last=school_04__negative__happiness [accepted] | 437.3s | 0.96 items/s
# [progress] labeled=430 (acc=376, rej=54) | last=school_05__neutral__anger [rejected] | 449.9s | 0.96 items/s
# [progress] labeled=440 (acc=385, rej=55) | last=school_05__negative__surprise [rejected] | 459.9s | 0.96 items/s
# [progress] labeled=450 (acc=395, rej=55) | last=school_06__neutral__happiness [accepted] | 470.3s | 0.96 items/s
# [progress] labeled=460 (acc=402, rej=58) | last=school_07__positive__anger [accepted] | 480.2s | 0.96 items/s
# [progress] labeled=470 (acc=411, rej=59) | last=school_07__neutral__surprise [accepted] | 491.0s | 0.96 items/s
# [progress] labeled=480 (acc=419, rej=61) | last=school_08__positive__happiness [accepted] | 499.7s | 0.96 items/s
# [progress] labeled=490 (acc=428, rej=62) | last=school_08__negative__anger [accepted] | 510.2s | 0.96 items/s
# [progress] labeled=500 (acc=436, rej=64) | last=school_09__positive__surprise [accepted] | 518.6s | 0.96 items/s
# [progress] labeled=510 (acc=446, rej=64) | last=school_09__negative__happiness [accepted] | 528.6s | 0.96 items/s
# [progress] labeled=520 (acc=454, rej=66) | last=school_10__neutral__anger [accepted] | 538.3s | 0.97 items/s
# [progress] labeled=530 (acc=460, rej=70) | last=school_10__negative__surprise [rejected] | 547.2s | 0.97 items/s
# [progress] labeled=540 (acc=470, rej=70) | last=school_11__neutral__happiness [accepted] | 556.8s | 0.97 items/s
# [progress] labeled=550 (acc=479, rej=71) | last=school_12__positive__anger [accepted] | 567.9s | 0.97 items/s
# [progress] labeled=560 (acc=486, rej=74) | last=school_12__neutral__surprise [accepted] | 577.8s | 0.97 items/s
# [progress] labeled=570 (acc=493, rej=77) | last=school_13__positive__happiness [accepted] | 587.7s | 0.97 items/s
# [progress] labeled=580 (acc=501, rej=79) | last=school_13__negative__anger [accepted] | 597.1s | 0.97 items/s
# [progress] labeled=590 (acc=509, rej=81) | last=school_14__positive__surprise [accepted] | 606.4s | 0.97 items/s
# [progress] labeled=600 (acc=516, rej=84) | last=school_14__negative__happiness [rejected] | 616.5s | 0.97 items/s
# [progress] labeled=610 (acc=525, rej=85) | last=school_15__neutral__anger [accepted] | 627.0s | 0.97 items/s
# [progress] labeled=620 (acc=531, rej=89) | last=school_15__negative__surprise [rejected] | 637.5s | 0.97 items/s
# [progress] labeled=630 (acc=538, rej=92) | last=school_16__neutral__happiness [accepted] | 647.6s | 0.97 items/s
# [progress] labeled=640 (acc=545, rej=95) | last=school_17__positive__anger [accepted] | 656.8s | 0.97 items/s
# [progress] labeled=650 (acc=553, rej=97) | last=school_17__neutral__surprise [accepted] | 666.6s | 0.98 items/s
# [progress] labeled=660 (acc=561, rej=99) | last=school_18__positive__happiness [accepted] | 677.2s | 0.97 items/s
# [progress] labeled=670 (acc=571, rej=99) | last=school_18__negative__anger [accepted] | 687.4s | 0.97 items/s
# [progress] labeled=680 (acc=580, rej=100) | last=school_19__positive__surprise [accepted] | 697.8s | 0.97 items/s
# [progress] labeled=690 (acc=588, rej=102) | last=school_19__negative__happiness [accepted] | 708.4s | 0.97 items/s
# [progress] labeled=700 (acc=596, rej=104) | last=relation_00__neutral__anger [accepted] | 718.0s | 0.97 items/s
# [progress] labeled=710 (acc=606, rej=104) | last=relation_00__negative__surprise [accepted] | 728.2s | 0.98 items/s
# [progress] labeled=720 (acc=615, rej=105) | last=relation_01__neutral__happiness [accepted] | 737.5s | 0.98 items/s
# [progress] labeled=730 (acc=624, rej=106) | last=relation_02__positive__anger [rejected] | 749.0s | 0.97 items/s
# [progress] labeled=740 (acc=634, rej=106) | last=relation_02__neutral__surprise [accepted] | 760.1s | 0.97 items/s
# [progress] labeled=750 (acc=644, rej=106) | last=relation_03__positive__happiness [accepted] | 770.4s | 0.97 items/s
# [progress] labeled=760 (acc=654, rej=106) | last=relation_03__negative__anger [accepted] | 780.0s | 0.97 items/s
# [progress] labeled=770 (acc=662, rej=108) | last=relation_04__positive__surprise [accepted] | 790.2s | 0.97 items/s
# [progress] labeled=780 (acc=671, rej=109) | last=relation_04__negative__happiness [accepted] | 800.3s | 0.97 items/s
# [progress] labeled=790 (acc=679, rej=111) | last=relation_05__neutral__anger [accepted] | 810.3s | 0.97 items/s
# [progress] labeled=800 (acc=685, rej=115) | last=relation_05__negative__surprise [rejected] | 820.9s | 0.97 items/s
# [progress] labeled=810 (acc=695, rej=115) | last=relation_06__neutral__happiness [accepted] | 829.9s | 0.98 items/s
# [progress] labeled=820 (acc=703, rej=117) | last=relation_07__positive__anger [accepted] | 840.6s | 0.98 items/s
# [progress] labeled=830 (acc=712, rej=118) | last=relation_07__neutral__surprise [accepted] | 849.5s | 0.98 items/s
# [progress] labeled=840 (acc=720, rej=120) | last=relation_08__positive__happiness [accepted] | 859.2s | 0.98 items/s
# [progress] labeled=850 (acc=729, rej=121) | last=relation_08__negative__anger [accepted] | 868.4s | 0.98 items/s
# [progress] labeled=860 (acc=738, rej=122) | last=relation_09__positive__surprise [accepted] | 878.4s | 0.98 items/s
# [progress] labeled=870 (acc=748, rej=122) | last=relation_09__negative__happiness [accepted] | 887.8s | 0.98 items/s
# [progress] labeled=880 (acc=756, rej=124) | last=relation_10__neutral__anger [accepted] | 897.5s | 0.98 items/s
# [progress] labeled=890 (acc=764, rej=126) | last=relation_10__negative__surprise [rejected] | 908.2s | 0.98 items/s
# [progress] labeled=900 (acc=773, rej=127) | last=relation_11__neutral__happiness [accepted] | 919.9s | 0.98 items/s
# [progress] labeled=910 (acc=782, rej=128) | last=relation_12__positive__anger [accepted] | 929.5s | 0.98 items/s
# [progress] labeled=920 (acc=789, rej=131) | last=relation_12__neutral__surprise [rejected] | 938.6s | 0.98 items/s
# [progress] labeled=930 (acc=795, rej=135) | last=relation_13__positive__happiness [accepted] | 948.1s | 0.98 items/s
# [progress] labeled=940 (acc=804, rej=136) | last=relation_13__negative__anger [accepted] | 957.4s | 0.98 items/s
# [progress] labeled=950 (acc=811, rej=139) | last=relation_14__positive__surprise [accepted] | 967.3s | 0.98 items/s
# [progress] labeled=960 (acc=819, rej=141) | last=relation_14__negative__happiness [accepted] | 975.4s | 0.98 items/s
# [progress] labeled=970 (acc=828, rej=142) | last=relation_15__neutral__anger [accepted] | 984.5s | 0.99 items/s
# [progress] labeled=980 (acc=838, rej=142) | last=relation_15__negative__surprise [accepted] | 993.6s | 0.99 items/s
# [progress] labeled=990 (acc=847, rej=143) | last=relation_16__neutral__happiness [accepted] | 1002.8s | 0.99 items/s
# [progress] labeled=1000 (acc=855, rej=145) | last=relation_17__positive__anger [accepted] | 1014.1s | 0.99 items/s
# [progress] labeled=1010 (acc=865, rej=145) | last=relation_17__neutral__surprise [accepted] | 1023.4s | 0.99 items/s
# [progress] labeled=1020 (acc=874, rej=146) | last=relation_18__positive__happiness [accepted] | 1034.4s | 0.99 items/s
# [progress] labeled=1030 (acc=884, rej=146) | last=relation_18__negative__anger [accepted] | 1043.8s | 0.99 items/s
# [progress] labeled=1040 (acc=892, rej=148) | last=relation_19__positive__surprise [rejected] | 1055.2s | 0.99 items/s
# [progress] labeled=1050 (acc=902, rej=148) | last=relation_19__negative__happiness [accepted] | 1066.5s | 0.98 items/s
# [progress] labeled=1060 (acc=910, rej=150) | last=shopping_00__neutral__anger [accepted] | 1077.0s | 0.98 items/s
# [progress] labeled=1070 (acc=918, rej=152) | last=shopping_00__negative__surprise [rejected] | 1086.0s | 0.99 items/s
# [progress] labeled=1080 (acc=926, rej=154) | last=shopping_01__neutral__happiness [accepted] | 1096.3s | 0.99 items/s
# [progress] labeled=1090 (acc=934, rej=156) | last=shopping_02__positive__anger [accepted] | 1107.3s | 0.98 items/s
# [progress] labeled=1100 (acc=943, rej=157) | last=shopping_02__neutral__surprise [accepted] | 1116.9s | 0.98 items/s
# [progress] labeled=1110 (acc=949, rej=161) | last=shopping_03__positive__happiness [accepted] | 1127.1s | 0.98 items/s
# [progress] labeled=1120 (acc=958, rej=162) | last=shopping_03__negative__anger [accepted] | 1137.7s | 0.98 items/s
# [progress] labeled=1130 (acc=966, rej=164) | last=shopping_04__positive__surprise [accepted] | 1148.7s | 0.98 items/s
# [progress] labeled=1140 (acc=974, rej=166) | last=shopping_04__negative__happiness [rejected] | 1158.5s | 0.98 items/s
# [progress] labeled=1150 (acc=981, rej=169) | last=shopping_05__neutral__anger [rejected] | 1169.8s | 0.98 items/s
# [progress] labeled=1160 (acc=987, rej=173) | last=shopping_05__negative__surprise [rejected] | 1183.9s | 0.98 items/s
# [progress] labeled=1170 (acc=996, rej=174) | last=shopping_06__neutral__happiness [accepted] | 1193.3s | 0.98 items/s
# [progress] labeled=1180 (acc=1004, rej=176) | last=shopping_07__positive__anger [accepted] | 1209.5s | 0.98 items/s
# [progress] labeled=1190 (acc=1012, rej=178) | last=shopping_07__neutral__surprise [accepted] | 1222.4s | 0.97 items/s
# [progress] labeled=1200 (acc=1019, rej=181) | last=shopping_08__positive__happiness [accepted] | 1234.9s | 0.97 items/s
# [progress] labeled=1210 (acc=1029, rej=181) | last=shopping_08__negative__anger [accepted] | 1246.0s | 0.97 items/s
# [progress] labeled=1220 (acc=1038, rej=182) | last=shopping_09__positive__surprise [accepted] | 1257.8s | 0.97 items/s
# [progress] labeled=1230 (acc=1046, rej=184) | last=shopping_09__negative__happiness [rejected] | 1268.9s | 0.97 items/s
# [progress] labeled=1240 (acc=1054, rej=186) | last=shopping_10__neutral__anger [rejected] | 1281.6s | 0.97 items/s
# [progress] labeled=1250 (acc=1064, rej=186) | last=shopping_10__negative__surprise [accepted] | 1292.8s | 0.97 items/s
# [progress] labeled=1260 (acc=1074, rej=186) | last=shopping_11__neutral__happiness [accepted] | 1303.1s | 0.97 items/s
# [progress] labeled=1270 (acc=1083, rej=187) | last=shopping_12__positive__anger [accepted] | 1319.1s | 0.96 items/s
# [progress] labeled=1280 (acc=1089, rej=191) | last=shopping_12__neutral__surprise [rejected] | 1331.1s | 0.96 items/s
# [progress] labeled=1290 (acc=1096, rej=194) | last=shopping_13__positive__happiness [accepted] | 1341.8s | 0.96 items/s
# [progress] labeled=1300 (acc=1106, rej=194) | last=shopping_13__negative__anger [accepted] | 1357.9s | 0.96 items/s
# [progress] labeled=1310 (acc=1114, rej=196) | last=shopping_14__positive__surprise [accepted] | 1370.4s | 0.96 items/s
# [progress] labeled=1320 (acc=1123, rej=197) | last=shopping_14__negative__happiness [rejected] | 1380.0s | 0.96 items/s
# [progress] labeled=1330 (acc=1128, rej=202) | last=shopping_15__neutral__anger [accepted] | 1395.1s | 0.95 items/s
# [progress] labeled=1340 (acc=1132, rej=208) | last=shopping_15__negative__surprise [rejected] | 1406.2s | 0.95 items/s
# [progress] labeled=1350 (acc=1141, rej=209) | last=shopping_16__neutral__happiness [accepted] | 1416.2s | 0.95 items/s
# [progress] labeled=1360 (acc=1149, rej=211) | last=shopping_17__positive__anger [accepted] | 1431.0s | 0.95 items/s
# [progress] labeled=1370 (acc=1158, rej=212) | last=shopping_17__neutral__surprise [accepted] | 1442.9s | 0.95 items/s
# [progress] labeled=1380 (acc=1167, rej=213) | last=shopping_18__positive__happiness [accepted] | 1454.2s | 0.95 items/s
# [progress] labeled=1390 (acc=1177, rej=213) | last=shopping_18__negative__anger [accepted] | 1464.4s | 0.95 items/s
# [progress] labeled=1400 (acc=1183, rej=217) | last=shopping_19__positive__surprise [accepted] | 1479.0s | 0.95 items/s
# [progress] labeled=1410 (acc=1190, rej=220) | last=shopping_19__negative__happiness [rejected] | 1489.7s | 0.95 items/s
# [progress] labeled=1420 (acc=1197, rej=223) | last=administration_00__neutral__anger [accepted] | 1501.3s | 0.95 items/s
# [progress] labeled=1430 (acc=1205, rej=225) | last=administration_00__negative__surprise [rejected] | 1512.5s | 0.95 items/s
# [progress] labeled=1440 (acc=1214, rej=226) | last=administration_01__neutral__happiness [accepted] | 1523.2s | 0.95 items/s
# [progress] labeled=1450 (acc=1223, rej=227) | last=administration_02__positive__anger [accepted] | 1533.5s | 0.95 items/s
# [progress] labeled=1460 (acc=1233, rej=227) | last=administration_02__neutral__surprise [accepted] | 1543.5s | 0.95 items/s
# [progress] labeled=1470 (acc=1242, rej=228) | last=administration_03__positive__happiness [accepted] | 1554.9s | 0.95 items/s
# [progress] labeled=1480 (acc=1251, rej=229) | last=administration_03__negative__anger [accepted] | 1565.0s | 0.95 items/s
# [progress] labeled=1490 (acc=1259, rej=231) | last=administration_04__positive__surprise [accepted] | 1575.4s | 0.95 items/s
# [progress] labeled=1500 (acc=1269, rej=231) | last=administration_04__negative__happiness [accepted] | 1584.4s | 0.95 items/s
# [progress] labeled=1510 (acc=1279, rej=231) | last=administration_05__neutral__anger [accepted] | 1596.2s | 0.95 items/s
# [progress] labeled=1520 (acc=1287, rej=233) | last=administration_05__negative__surprise [rejected] | 1606.5s | 0.95 items/s
# [progress] labeled=1530 (acc=1296, rej=234) | last=administration_06__neutral__happiness [accepted] | 1616.9s | 0.95 items/s
# [progress] labeled=1540 (acc=1304, rej=236) | last=administration_07__positive__anger [accepted] | 1627.8s | 0.95 items/s
# [progress] labeled=1550 (acc=1312, rej=238) | last=administration_07__neutral__surprise [accepted] | 1638.1s | 0.95 items/s
# [progress] labeled=1560 (acc=1320, rej=240) | last=administration_08__positive__happiness [accepted] | 1648.5s | 0.95 items/s
# [progress] labeled=1570 (acc=1330, rej=240) | last=administration_08__negative__anger [accepted] | 1662.1s | 0.94 items/s
# [progress] labeled=1580 (acc=1338, rej=242) | last=administration_09__positive__surprise [accepted] | 1673.3s | 0.94 items/s
# [progress] labeled=1590 (acc=1348, rej=242) | last=administration_09__negative__happiness [accepted] | 1684.7s | 0.94 items/s
# [progress] labeled=1600 (acc=1358, rej=242) | last=administration_10__neutral__anger [accepted] | 1693.4s | 0.94 items/s
# [progress] labeled=1610 (acc=1366, rej=244) | last=administration_10__negative__surprise [rejected] | 1704.0s | 0.94 items/s
# [progress] labeled=1620 (acc=1375, rej=245) | last=administration_11__neutral__happiness [accepted] | 1713.3s | 0.95 items/s
# [progress] labeled=1630 (acc=1384, rej=246) | last=administration_12__positive__anger [accepted] | 1723.5s | 0.95 items/s
# [progress] labeled=1640 (acc=1394, rej=246) | last=administration_12__neutral__surprise [accepted] | 1732.8s | 0.95 items/s
# [progress] labeled=1650 (acc=1401, rej=249) | last=administration_13__positive__happiness [accepted] | 1744.2s | 0.95 items/s
# [progress] labeled=1660 (acc=1409, rej=251) | last=administration_13__negative__anger [accepted] | 1756.2s | 0.95 items/s
# [progress] labeled=1670 (acc=1412, rej=258) | last=administration_14__positive__surprise [rejected] | 1766.5s | 0.95 items/s
# [progress] labeled=1680 (acc=1420, rej=260) | last=administration_14__negative__happiness [accepted] | 1776.4s | 0.95 items/s
# [progress] labeled=1690 (acc=1427, rej=263) | last=administration_15__neutral__anger [rejected] | 1786.2s | 0.95 items/s
# [progress] labeled=1700 (acc=1437, rej=263) | last=administration_15__negative__surprise [accepted] | 1795.5s | 0.95 items/s
# [progress] labeled=1710 (acc=1446, rej=264) | last=administration_16__neutral__happiness [accepted] | 1805.3s | 0.95 items/s
# [progress] labeled=1720 (acc=1454, rej=266) | last=administration_17__positive__anger [accepted] | 1815.5s | 0.95 items/s
# [progress] labeled=1730 (acc=1463, rej=267) | last=administration_17__neutral__surprise [accepted] | 1825.2s | 0.95 items/s
# [progress] labeled=1740 (acc=1469, rej=271) | last=administration_18__positive__happiness [accepted] | 1833.5s | 0.95 items/s
# [progress] labeled=1750 (acc=1479, rej=271) | last=administration_18__negative__anger [accepted] | 1845.1s | 0.95 items/s
# [progress] labeled=1760 (acc=1487, rej=273) | last=administration_19__positive__surprise [rejected] | 1853.2s | 0.95 items/s
# [progress] labeled=1770 (acc=1492, rej=278) | last=administration_19__negative__happiness [accepted] | 1863.5s | 0.95 items/s
# [progress] labeled=1780 (acc=1498, rej=282) | last=health_00__neutral__anger [rejected] | 1873.5s | 0.95 items/s
# [progress] labeled=1790 (acc=1506, rej=284) | last=health_00__negative__surprise [accepted] | 1883.0s | 0.95 items/s
# [progress] labeled=1800 (acc=1515, rej=285) | last=health_01__neutral__happiness [accepted] | 1891.8s | 0.95 items/s
# [progress] labeled=1810 (acc=1522, rej=288) | last=health_02__positive__anger [accepted] | 1901.4s | 0.95 items/s
# [progress] labeled=1820 (acc=1532, rej=288) | last=health_02__neutral__surprise [accepted] | 1910.9s | 0.95 items/s
# [progress] labeled=1830 (acc=1539, rej=291) | last=health_03__positive__happiness [accepted] | 1919.2s | 0.95 items/s
# [progress] labeled=1840 (acc=1549, rej=291) | last=health_03__negative__anger [accepted] | 1928.4s | 0.95 items/s
# [progress] labeled=1850 (acc=1557, rej=293) | last=health_04__positive__surprise [accepted] | 1937.6s | 0.95 items/s
# [progress] labeled=1860 (acc=1567, rej=293) | last=health_04__negative__happiness [accepted] | 1947.3s | 0.96 items/s
# [progress] labeled=1870 (acc=1574, rej=296) | last=health_05__neutral__anger [accepted] | 1957.9s | 0.96 items/s
# [progress] labeled=1880 (acc=1584, rej=296) | last=health_05__negative__surprise [accepted] | 1968.4s | 0.96 items/s
# [progress] labeled=1890 (acc=1592, rej=298) | last=health_06__neutral__happiness [accepted] | 1977.9s | 0.96 items/s
# [progress] labeled=1900 (acc=1601, rej=299) | last=health_07__positive__anger [accepted] | 1987.7s | 0.96 items/s
# [progress] labeled=1910 (acc=1609, rej=301) | last=health_07__neutral__surprise [accepted] | 1998.6s | 0.96 items/s
# [progress] labeled=1920 (acc=1616, rej=304) | last=health_08__positive__happiness [accepted] | 2009.4s | 0.96 items/s
# [progress] labeled=1930 (acc=1624, rej=306) | last=health_08__negative__anger [accepted] | 2018.5s | 0.96 items/s
# [progress] labeled=1940 (acc=1631, rej=309) | last=health_09__positive__surprise [accepted] | 2028.0s | 0.96 items/s
# [progress] labeled=1950 (acc=1637, rej=313) | last=health_09__negative__happiness [accepted] | 2040.1s | 0.96 items/s
# [progress] labeled=1960 (acc=1643, rej=317) | last=health_10__neutral__anger [accepted] | 2049.6s | 0.96 items/s
# [progress] labeled=1970 (acc=1650, rej=320) | last=health_10__negative__surprise [rejected] | 2059.9s | 0.96 items/s
# [progress] labeled=1980 (acc=1659, rej=321) | last=health_11__neutral__happiness [accepted] | 2068.9s | 0.96 items/s
# [progress] labeled=1990 (acc=1668, rej=322) | last=health_12__positive__anger [accepted] | 2079.0s | 0.96 items/s
# [progress] labeled=2000 (acc=1675, rej=325) | last=health_12__neutral__surprise [accepted] | 2089.1s | 0.96 items/s
# [progress] labeled=2010 (acc=1683, rej=327) | last=health_13__positive__happiness [accepted] | 2100.9s | 0.96 items/s
# [progress] labeled=2020 (acc=1690, rej=330) | last=health_13__negative__anger [rejected] | 2111.7s | 0.96 items/s
# [progress] labeled=2030 (acc=1697, rej=333) | last=health_14__positive__surprise [accepted] | 2122.2s | 0.96 items/s
# [progress] labeled=2040 (acc=1706, rej=334) | last=health_14__negative__happiness [accepted] | 2131.3s | 0.96 items/s
# [progress] labeled=2050 (acc=1713, rej=337) | last=health_15__neutral__anger [rejected] | 2141.9s | 0.96 items/s
# [progress] labeled=2060 (acc=1723, rej=337) | last=health_15__negative__surprise [accepted] | 2151.1s | 0.96 items/s
# [progress] labeled=2070 (acc=1731, rej=339) | last=health_16__neutral__happiness [accepted] | 2160.8s | 0.96 items/s
# [progress] labeled=2080 (acc=1740, rej=340) | last=health_17__positive__anger [accepted] | 2170.4s | 0.96 items/s
# [progress] labeled=2090 (acc=1749, rej=341) | last=health_17__neutral__surprise [accepted] | 2179.7s | 0.96 items/s
# [progress] labeled=2100 (acc=1755, rej=345) | last=health_18__positive__happiness [accepted] | 2189.4s | 0.96 items/s
# [progress] labeled=2110 (acc=1764, rej=346) | last=health_18__negative__anger [accepted] | 2197.8s | 0.96 items/s
# [progress] labeled=2120 (acc=1770, rej=350) | last=health_19__positive__surprise [accepted] | 2210.3s | 0.96 items/s
# [progress] labeled=2130 (acc=1778, rej=352) | last=health_19__negative__happiness [accepted] | 2219.2s | 0.96 items/s
# [progress] labeled=2140 (acc=1784, rej=356) | last=living_00__neutral__anger [accepted] | 2230.4s | 0.96 items/s
# [progress] labeled=2150 (acc=1791, rej=359) | last=living_00__negative__surprise [rejected] | 2238.5s | 0.96 items/s
# [progress] labeled=2160 (acc=1801, rej=359) | last=living_01__neutral__happiness [accepted] | 2247.4s | 0.96 items/s
# [progress] labeled=2170 (acc=1809, rej=361) | last=living_02__positive__anger [accepted] | 2256.6s | 0.96 items/s
# [progress] labeled=2180 (acc=1816, rej=364) | last=living_02__neutral__surprise [accepted] | 2266.3s | 0.96 items/s
# [progress] labeled=2190 (acc=1824, rej=366) | last=living_03__positive__happiness [accepted] | 2276.4s | 0.96 items/s
# [progress] labeled=2200 (acc=1832, rej=368) | last=living_03__negative__anger [accepted] | 2286.7s | 0.96 items/s
# [progress] labeled=2210 (acc=1840, rej=370) | last=living_04__positive__surprise [accepted] | 2297.3s | 0.96 items/s
# [progress] labeled=2220 (acc=1847, rej=373) | last=living_04__negative__happiness [rejected] | 2308.2s | 0.96 items/s
# [progress] labeled=2230 (acc=1854, rej=376) | last=living_05__neutral__anger [rejected] | 2318.5s | 0.96 items/s
# [progress] labeled=2240 (acc=1863, rej=377) | last=living_05__negative__surprise [accepted] | 2328.4s | 0.96 items/s
# [progress] labeled=2250 (acc=1872, rej=378) | last=living_06__neutral__happiness [accepted] | 2337.7s | 0.96 items/s
# [progress] labeled=2260 (acc=1882, rej=378) | last=living_07__positive__anger [accepted] | 2347.1s | 0.96 items/s
# [progress] labeled=2270 (acc=1890, rej=380) | last=living_07__neutral__surprise [accepted] | 2356.7s | 0.96 items/s
# [progress] labeled=2280 (acc=1899, rej=381) | last=living_08__positive__happiness [accepted] | 2366.5s | 0.96 items/s
# [progress] labeled=2290 (acc=1909, rej=381) | last=living_08__negative__anger [accepted] | 2378.8s | 0.96 items/s
# [progress] labeled=2300 (acc=1916, rej=384) | last=living_09__positive__surprise [accepted] | 2388.7s | 0.96 items/s
# [progress] labeled=2310 (acc=1925, rej=385) | last=living_09__negative__happiness [accepted] | 2399.0s | 0.96 items/s
# [progress] labeled=2320 (acc=1932, rej=388) | last=living_10__neutral__anger [accepted] | 2409.5s | 0.96 items/s
# [progress] labeled=2330 (acc=1942, rej=388) | last=living_10__negative__surprise [accepted] | 2420.9s | 0.96 items/s
# [progress] labeled=2340 (acc=1949, rej=391) | last=living_11__neutral__happiness [accepted] | 2430.2s | 0.96 items/s
# [progress] labeled=2350 (acc=1957, rej=393) | last=living_12__positive__anger [accepted] | 2441.5s | 0.96 items/s
# [progress] labeled=2360 (acc=1965, rej=395) | last=living_12__neutral__surprise [accepted] | 2451.1s | 0.96 items/s
# [progress] labeled=2370 (acc=1973, rej=397) | last=living_13__positive__happiness [accepted] | 2462.4s | 0.96 items/s
# [progress] labeled=2380 (acc=1982, rej=398) | last=living_13__negative__anger [accepted] | 2473.9s | 0.96 items/s
# [progress] labeled=2390 (acc=1990, rej=400) | last=living_14__positive__surprise [accepted] | 2485.0s | 0.96 items/s
# [progress] labeled=2400 (acc=1997, rej=403) | last=living_14__negative__happiness [accepted] | 2495.0s | 0.96 items/s
# [progress] labeled=2410 (acc=2005, rej=405) | last=living_15__neutral__anger [accepted] | 2507.2s | 0.96 items/s
# [progress] labeled=2420 (acc=2012, rej=408) | last=living_15__negative__surprise [rejected] | 2518.7s | 0.96 items/s
# [progress] labeled=2430 (acc=2022, rej=408) | last=living_16__neutral__happiness [accepted] | 2528.7s | 0.96 items/s
# [progress] labeled=2440 (acc=2031, rej=409) | last=living_17__positive__anger [accepted] | 2538.5s | 0.96 items/s
# [progress] labeled=2450 (acc=2041, rej=409) | last=living_17__neutral__surprise [accepted] | 2548.7s | 0.96 items/s
# [progress] labeled=2460 (acc=2050, rej=410) | last=living_18__positive__happiness [accepted] | 2560.0s | 0.96 items/s
# [progress] labeled=2470 (acc=2059, rej=411) | last=living_18__negative__anger [accepted] | 2569.7s | 0.96 items/s
# [progress] labeled=2480 (acc=2066, rej=414) | last=living_19__positive__surprise [accepted] | 2578.9s | 0.96 items/s
# [progress] labeled=2490 (acc=2075, rej=415) | last=living_19__negative__happiness [accepted] | 2588.7s | 0.96 items/s
# [progress] labeled=2500 (acc=2082, rej=418) | last=travel_00__neutral__anger [accepted] | 2598.1s | 0.96 items/s
# [progress] labeled=2510 (acc=2091, rej=419) | last=travel_00__negative__surprise [accepted] | 2607.9s | 0.96 items/s
# [progress] labeled=2520 (acc=2100, rej=420) | last=travel_01__neutral__happiness [accepted] | 2617.6s | 0.96 items/s
# [progress] labeled=2530 (acc=2107, rej=423) | last=travel_02__positive__anger [accepted] | 2626.4s | 0.96 items/s
# [progress] labeled=2540 (acc=2115, rej=425) | last=travel_02__neutral__surprise [accepted] | 2634.9s | 0.96 items/s
# [progress] labeled=2550 (acc=2121, rej=429) | last=travel_03__positive__happiness [accepted] | 2645.8s | 0.96 items/s
# [progress] labeled=2560 (acc=2131, rej=429) | last=travel_03__negative__anger [accepted] | 2655.7s | 0.96 items/s
# [progress] labeled=2570 (acc=2137, rej=433) | last=travel_04__positive__surprise [accepted] | 2665.1s | 0.96 items/s
# [progress] labeled=2580 (acc=2144, rej=436) | last=travel_04__negative__happiness [accepted] | 2676.8s | 0.96 items/s
# [progress] labeled=2590 (acc=2153, rej=437) | last=travel_05__neutral__anger [accepted] | 2687.8s | 0.96 items/s
# [progress] labeled=2600 (acc=2162, rej=438) | last=travel_05__negative__surprise [accepted] | 2699.6s | 0.96 items/s
# [progress] labeled=2610 (acc=2170, rej=440) | last=travel_06__neutral__happiness [accepted] | 2708.3s | 0.96 items/s
# [progress] labeled=2620 (acc=2177, rej=443) | last=travel_07__positive__anger [rejected] | 2718.6s | 0.96 items/s
# [progress] labeled=2630 (acc=2184, rej=446) | last=travel_07__neutral__surprise [rejected] | 2728.0s | 0.96 items/s
# [progress] labeled=2640 (acc=2193, rej=447) | last=travel_08__positive__happiness [accepted] | 2736.9s | 0.96 items/s
# [progress] labeled=2650 (acc=2203, rej=447) | last=travel_08__negative__anger [accepted] | 2745.4s | 0.97 items/s
# [progress] labeled=2660 (acc=2213, rej=447) | last=travel_09__positive__surprise [accepted] | 2755.6s | 0.97 items/s
# [progress] labeled=2670 (acc=2220, rej=450) | last=travel_09__negative__happiness [rejected] | 2765.0s | 0.97 items/s
# [progress] labeled=2680 (acc=2228, rej=452) | last=travel_10__neutral__anger [accepted] | 2776.3s | 0.97 items/s
# [progress] labeled=2690 (acc=2237, rej=453) | last=travel_10__negative__surprise [accepted] | 2786.2s | 0.97 items/s
# [progress] labeled=2700 (acc=2245, rej=455) | last=travel_11__neutral__happiness [accepted] | 2797.1s | 0.97 items/s
# [progress] labeled=2710 (acc=2254, rej=456) | last=travel_12__positive__anger [accepted] | 2808.4s | 0.96 items/s
# [progress] labeled=2720 (acc=2263, rej=457) | last=travel_12__neutral__surprise [accepted] | 2817.9s | 0.97 items/s
# [progress] labeled=2730 (acc=2271, rej=459) | last=travel_13__positive__happiness [accepted] | 2829.8s | 0.96 items/s
# [progress] labeled=2740 (acc=2281, rej=459) | last=travel_13__negative__anger [accepted] | 2839.2s | 0.97 items/s
# [progress] labeled=2750 (acc=2287, rej=463) | last=travel_14__positive__surprise [accepted] | 2849.3s | 0.97 items/s
# [progress] labeled=2760 (acc=2296, rej=464) | last=travel_14__negative__happiness [accepted] | 2861.2s | 0.96 items/s
# [progress] labeled=2770 (acc=2305, rej=465) | last=travel_15__neutral__anger [accepted] | 2875.3s | 0.96 items/s
# [progress] labeled=2780 (acc=2313, rej=467) | last=travel_15__negative__surprise [rejected] | 2886.7s | 0.96 items/s
# [progress] labeled=2790 (acc=2321, rej=469) | last=travel_16__neutral__happiness [accepted] | 2900.3s | 0.96 items/s
# [progress] labeled=2800 (acc=2328, rej=472) | last=travel_17__positive__anger [accepted] | 2912.2s | 0.96 items/s
# [progress] labeled=2810 (acc=2338, rej=472) | last=travel_17__neutral__surprise [accepted] | 2924.2s | 0.96 items/s
# [progress] labeled=2820 (acc=2347, rej=473) | last=travel_18__positive__happiness [accepted] | 2938.9s | 0.96 items/s
# [progress] labeled=2830 (acc=2357, rej=473) | last=travel_18__negative__anger [accepted] | 2953.7s | 0.96 items/s
# [progress] labeled=2840 (acc=2364, rej=476) | last=travel_19__positive__surprise [accepted] | 2968.2s | 0.96 items/s
# [progress] labeled=2850 (acc=2373, rej=477) | last=travel_19__negative__happiness [rejected] | 2981.4s | 0.96 items/s
#
# [OK] sev completed. Labeled 2853 items, skipped 27 items.
#      Accepted: 2375 | Rejected: 478
#      Time: 2985.0s | Rate: 0.96 items/s
#      Output:
#        - /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled/sev/accepted.jsonl
#        - /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled/sev/rejected.jsonl
#
# ============================================================
# 📊 ACCURACY STATISTICS - SEV
# ============================================================
#
# 🎯 Overall Accuracy: 2375/2853 = 83.25%
#
# 📈 Accuracy by Emotion:
# ------------------------------------------------------------
# Emotion         Accepted     Total      Accuracy
# ------------------------------------------------------------
# anger           402          475         84.63%
# disgust         448          476         94.12%
# fear            389          476         81.72%
# happiness       420          475         88.42%
# sadness         367          475         77.26%
# surprise        349          476         73.32%
#
# 📉 Accuracy by Valence:
# ------------------------------------------------------------
# Valence         Accepted     Total      Accuracy
# ------------------------------------------------------------
# negative        712          954         74.63%
# neutral         836          951         87.91%
# positive        827          948         87.24%
# ============================================================

# %%
import sys
sys.argv = [
    "program",
    "--input_dir", "/content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled",
    "--dataset", "sev"
]

# %%
# scripts/01_emotion_elicited_generation_prompt_based/3_generate_accuracy_stats.py
"""
Accuracy Statistics Generation Script

Reads accepted and rejected files from script 2, calculates accuracy by emotion and valence

-  Input: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/labeled/{dataset_name}/{accepted|rejected}.jsonl
-  Output: outputs/{model_name}/01_emotion_elicited_generation_prompt_based/labeled/{dataset_name}/accuracy_stats.json
"""

import json, argparse
from pathlib import Path
from collections import defaultdict


def generate_accuracy_stats(labeled_dir: Path, dataset_name: str):
    """
    Generate accuracy statistics for specified dataset
    """

    dataset_dir = labeled_dir / dataset_name
    accepted_path = dataset_dir / "accepted.jsonl"
    rejected_path = dataset_dir / "rejected.jsonl"
    stats_path = dataset_dir / "accuracy_stats.json"

    if not dataset_dir.exists():
        print(f"[ERROR] Dataset directory not found: {dataset_dir}")
        return None

    # Statistics dictionaries
    stats_by_emotion = defaultdict(lambda: {"total": 0, "accepted": 0, "rejected": 0})
    stats_by_valence = defaultdict(lambda: {"total": 0, "accepted": 0, "rejected": 0})

    total_accepted = 0
    total_rejected = 0

    # Read accepted
    if accepted_path.exists():
        print(f"Reading {accepted_path}...")
        with open(accepted_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    item = json.loads(line)
                    emotion = item.get("emotion", "unknown")
                    valence = item.get("valence", "unknown")

                    stats_by_emotion[emotion]["total"] += 1
                    stats_by_emotion[emotion]["accepted"] += 1

                    stats_by_valence[valence]["total"] += 1
                    stats_by_valence[valence]["accepted"] += 1

                    total_accepted += 1
                except json.JSONDecodeError:
                    continue
    else:
        print(f"[WARNING] Accepted file not found: {accepted_path}")

    # Read rejected
    if rejected_path.exists():
        print(f"Reading {rejected_path}...")
        with open(rejected_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue
                try:
                    item = json.loads(line)
                    emotion = item.get("emotion", "unknown")
                    valence = item.get("valence", "unknown")

                    stats_by_emotion[emotion]["total"] += 1
                    stats_by_emotion[emotion]["rejected"] += 1

                    stats_by_valence[valence]["total"] += 1
                    stats_by_valence[valence]["rejected"] += 1

                    total_rejected += 1
                except json.JSONDecodeError:
                    continue
    else:
        print(f"[WARNING] Rejected file not found: {rejected_path}")

    # Calculate accuracy
    for emotion in stats_by_emotion:
        total = stats_by_emotion[emotion]["total"]
        accepted = stats_by_emotion[emotion]["accepted"]
        stats_by_emotion[emotion]["accuracy"] = round(accepted / total * 100, 2) if total > 0 else 0.0

    for valence in stats_by_valence:
        total = stats_by_valence[valence]["total"]
        accepted = stats_by_valence[valence]["accepted"]
        stats_by_valence[valence]["accuracy"] = round(accepted / total * 100, 2) if total > 0 else 0.0

    # Overall statistics
    total_samples = total_accepted + total_rejected
    overall_accuracy = round(total_accepted / total_samples * 100, 2) if total_samples > 0 else 0.0

    # Build statistics result
    stats = {
        "dataset": dataset_name,
        "overall": {
            "total_samples": total_samples,
            "accepted": total_accepted,
            "rejected": total_rejected,
            "accuracy": overall_accuracy
        },
        "by_emotion": dict(stats_by_emotion),
        "by_valence": dict(stats_by_valence)
    }

    # Save statistics file
    with open(stats_path, "w", encoding="utf-8") as f:
        json.dump(stats, f, ensure_ascii=False, indent=2)

    return stats, stats_path


def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("--input_dir", type=str, default=None,
                       help="labeled Labeled directory path outputs/llama32_3b/01_emotion_elicited_generation_prompt_based/labeled")
    parser.add_argument("--both", action="store_true",
                       help="sev test_set Process both sev and test_set datasets")
    parser.add_argument("--model_name", type=str, default="llama32_3b",
                       help="Model folder name")
    parser.add_argument("--dataset", type=str, default=None,
                       help="Dataset name (sev, test_set)")
    args = parser.parse_args()

    # Determine labeled directory path
    if args.both or (not args.input_dir and not args.dataset):
        labeled_dir = Path("/content/drive/MyDrive/Various-Model/outputs") / args.model_name / "01_emotion_elicited_generation_prompt_based" / "labeled"

    elif args.input_dir:
        labeled_dir = Path(args.input_dir)
    else:
        parser.error(" --input_dir 或 --both | Must specify --input_dir or --both")
        return

    if not labeled_dir.exists():
        print(f"[ERROR] Labeled directory not found: {labeled_dir}")
        return

    # Determine datasets to process
    if args.both:
        datasets = ["sev", "test_set"]
    elif args.dataset:
        datasets = [args.dataset]
    else:
        # Auto-discover all dataset folders
        datasets = [d.name for d in labeled_dir.iterdir() if d.is_dir()]

    if not datasets:
        print(f"[ERROR] No datasets found in {labeled_dir}")
        return

    print("=" * 70)
    print("Generating Accuracy Statistics")
    print("=" * 70)

    for dataset_name in datasets:
        result = generate_accuracy_stats(labeled_dir, dataset_name)

        if result:
            stats, stats_path = result

            print(f"\n📊 {dataset_name.upper()} :")
            print(f"   File: {stats_path}")
            print(f"   Total: {stats['overall']['total_samples']}")
            print(f"   Accepted: {stats['overall']['accepted']}")
            print(f"   Rejected: {stats['overall']['rejected']}")
            print(f"   Overall Accuracy: {stats['overall']['accuracy']}%")

            print(f"\n   By Emotion:")
            for emotion in sorted(stats['by_emotion'].keys()):
                e_stats = stats['by_emotion'][emotion]
                print(f"      {emotion:12s}: {e_stats['accepted']:4d}/{e_stats['total']:4d} = {e_stats['accuracy']:6.2f}%")

            if stats['by_valence']:
                print(f"\n   By Valence:")
                for valence in sorted(stats['by_valence'].keys()):
                    v_stats = stats['by_valence'][valence]
                    print(f"      {valence:12s}: {v_stats['accepted']:4d}/{v_stats['total']:4d} = {v_stats['accuracy']:6.2f}%")

    print("\n" + "=" * 70)
    print("✅ Statistics generation completed!")
    print("=" * 70)


if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# Generating Accuracy Statistics
# ======================================================================
# Reading /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled/sev/accepted.jsonl...
# Reading /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled/sev/rejected.jsonl...
#
# 📊 SEV :
#    File: /content/drive/MyDrive/Various-Model/outputs/openai_gpt_5_nano/01_emotion_elicited_generation_prompt_based/labeled/sev/accuracy_stats.json
#    Total: 2829
#    Accepted: 2352
#    Rejected: 477
#    Overall Accuracy: 83.14%
#
#    By Emotion:
#       anger       :  398/ 471 =  84.50%
#       disgust     :  444/ 472 =  94.07%
#       fear        :  385/ 472 =  81.57%
#       happiness   :  416/ 471 =  88.32%
#       sadness     :  364/ 471 =  77.28%
#       surprise    :  345/ 472 =  73.09%
#
#    By Valence:
#       negative    :  704/ 945 =  74.50%
#       neutral     :  827/ 942 =  87.79%
#       positive    :  821/ 942 =  87.15%
#
# ======================================================================
# ✅ Statistics generation completed!
# ======================================================================
